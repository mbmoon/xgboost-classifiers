# %% [markdown]
# ### Local Binary Patterns + XGBoost optimization
#
# Вибір оптимальних параметрів для вирішення задач класифікації являється важливою та ресурсо-затратною задачею. В даній роботі буде запропонована одна із можливих реалізацій алгоритму підбору значеть конфігурації для XGBoost.
#
# Щоб підібрати оптимальні параметри для XGBoost, можна використати метод Grid Search для пошуку найкращих комбінацій значень гіперпараметрів.
#
# Пропонований підхід
#
#     Grid Search із перебором параметрів:
#         Cтворюємо сітку значень для n_estimators, max_depth, і eta.
#         Перевіримо кожну комбінацію цих параметрів шляхом повного навчання і оцінки класифікатора на тестових даних.
#         Також розглянемо розширення сітки додатковими параметрами для LBP.
#
#     Оцінка моделі:
#         Під час Grid Search використовуємо метрики (наприклад, accuracy) для вибору найкращої моделі.
#         Результати будемо зберігати для порівняння.
#
#     Реалізація:
#         До існуючої реалізації класифікатора додати функцію, яка виконуватиме Grid Search.
#         Організувати збереження результатів у вигляді таблиці або списку для аналізу.
#         Змінити функцію train_xgboost_classifier, щоб вона підтримувала гіперпараметри, що надходять як аргументи.

# %% [markdown]
# #### Імпортуємо необхідні бібліотеки
#
# З головного тут XGBoost та local_binary_pattern

# %%
import numpy as np
import cv2
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
import xgboost as xgb
import random
import matplotlib.pyplot as plt
from matplotlib.cm import get_cmap
from skimage.feature import local_binary_pattern
import time

# %%
import warnings
# Вимкнути всі попередження для видаленн зайвої інформації з консолі
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Функції виділення ознак
#
#
# LBP фокусується на текстурі, тому додавання інформації про колір може значно розширити можливості класифікатора.
# В даному дослідженні до LBP ознак буде додано інформацію значення пікселя в каналі RGB.

# %%
def prepare_data_with_colored_mask(image, mask, color_to_class, pixel_sample_percentage):
    """
    Вибирає координати та мітки із кольорової маски для тренування та генерує маску тренувальних пікселів.
    
    Parameters:
        image: Вхідне RGB-зображення.
        mask: Вхідна кольорова маска (BGR), яка вказує на мітки класів.
        color_to_class: Словник, що зв'язує кольори маски з індексами класів.
        pixel_sample_percentage: Відсоток пікселів для вибору в тренувальну підвибірку.
    
    Returns:
        sampled_coordinates: Список координат [(y, x)] вибраних пікселів.
        sampled_labels: Список міток класів для вибраних пікселів.
        temp_training_mask: Проміжна маска, що містить лише використовувані у тренуванні пікселі.
    """
    coordinates = []
    labels = []
    
    # Ініціалізуємо порожню маску для візуалізації тренувальних пікселів
    training_mask = np.ones_like(mask) * 255  # Маска спочатку біла (не використані пікселі)
    
    # Проходимо через пікселі вхідної маски
    for y in range(mask.shape[0]):
        for x in range(mask.shape[1]):
            b, g, r = mask[y, x]  # OpenCV використовує формат BGR
            color = (r, g, b)
            if color in color_to_class:
                coordinates.append((y, x))
                labels.append(color_to_class[color])
                # Копіюємо кольори з оригінальної маски в проміжну маску
                training_mask[y, x] = mask[y, x]
            elif color == (255, 255, 255):  # Ігноруємо білі пікселі
                continue

    # Перемішуємо та відбираємо пікселі
    combined = list(zip(coordinates, labels))
    random.shuffle(combined)
    coordinates, labels = zip(*combined)
    
    # Вибираємо підмножину пікселів для тренування
    sample_size = int(len(coordinates) * pixel_sample_percentage)
    sampled_coordinates = coordinates[:sample_size]
    sampled_labels = labels[:sample_size]
    
    # Змінюємо training_mask так, щоб залишилася тільки підвибірка
    temp_training_mask = np.ones_like(mask) * 255  # Створюємо нову маску з білим фоном
    for (y, x) in sampled_coordinates:
        temp_training_mask[y, x] = mask[y, x]  # Копіюємо тільки координати вибірки
    
    # Повертаємо результати
    return sampled_coordinates, sampled_labels, temp_training_mask

# %% [markdown]
# ###  Реалізація Grid Search

# %%
def grid_search_xgboost(features, labels, param_grid):
    """
    Виконує Grid Search для підбору оптимальних параметрів XGBoost з вимірюванням часу виконання.
    Покращено для відображення ТОП-5 найкращих параметрів.

    Parameters:
        features: Матриця ознак для тренування.
        labels: Відповідні класи для ознак.
        param_grid: Словник параметрів для Grid Search:
            {
                'n_estimators': [100, 200, 300],
                'max_depth': [4, 6, 8],
                'eta': [0.05, 0.1, 0.3]
            }

    Returns:
        best_params: Найкращі параметри після Grid Search.
        top_params: ТОП-5 найкращих параметрів (з найбільшим accuracy).
        results: Результати для всіх комбінацій параметрів.
    """
    from sklearn.model_selection import train_test_split
    from sklearn.metrics import accuracy_score
    import xgboost as xgb
    import time

    # Розбиваємо дані на тренувальні й тестові
    X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.3, random_state=42)
    results = []  # Список для результатів (accuracy та час для кожної комбінації)

    # Перебір усіх комбінацій параметрів
    for n_estimators in param_grid['n_estimators']:
        for max_depth in param_grid['max_depth']:
            for eta in param_grid['eta']:
                start_time = time.perf_counter()  # Відлік часу для цієї комбінації

                # Ініціалізація моделі з поточними параметрами
                model = xgb.XGBClassifier(
                    objective='multi:softmax',
                    num_class=4,
                    n_estimators=n_estimators,
                    max_depth=max_depth,
                    eta=eta
                )
                
                # Навчання моделі
                model.fit(X_train, y_train)
                
                # Передбачення тестових даних
                y_pred = model.predict(X_test)
                
                # Оцінка точності
                accuracy = accuracy_score(y_test, y_pred)
                
                # Обрахунок часу виконання
                elapsed_time = time.perf_counter() - start_time
                
                # Збереження результату
                results.append({
                    'n_estimators': n_estimators,
                    'max_depth': max_depth,
                    'eta': float(eta),  # Перетворюємо eta в float
                    'accuracy': float(accuracy),  # Перетворюємо accuracy в float
                    'time_elapsed': elapsed_time  # Час виконання в секундах
                })
                print(f"Evaluated params: n_estimators={n_estimators}, max_depth={max_depth}, eta={eta}, "
                      f"accuracy={accuracy:.4f}, time_elapsed={elapsed_time:.2f} seconds")

    # Сортуємо список результатів за значенням 'accuracy' (у спадному порядку)
    sorted_results = sorted(results, key=lambda x: x['accuracy'], reverse=True)

    # Пошук найкращих параметрів за accuracy
    best_params = sorted_results[0]

    # Топ-5 найкращих параметрів за accuracy
    top_params = sorted_results[:5]
    
    # Виведення найкращих параметрів
    print(f"\nBest Parameters: {best_params}")
    
    # Виведення ТОП-5 параметрів у зручному форматі
    print("\nTop 5 Parameters:")
    print(f"{'Rank':<5} {'n_estimators':<12} {'max_depth':<10} {'eta':<6} {'accuracy':<8} {'time(s)':<8}")
    for i, params in enumerate(top_params, start=1):
        print(f"{i:<5} {params['n_estimators']:<12} {params['max_depth']:<10} {params['eta']:<6.2f} "
              f"{params['accuracy']:<8.4f} {params['time_elapsed']:<8.2f}")

    return best_params, top_params, results

# %% [markdown]
# ### Оптимізація по часу
#
# Дана функція покликана надати оцінку моделі враховуючи два параметри Accuracy та Time. Для цього введено додатковий коефіцієнт який визначає важливість часу необхідного для тренування та роботи моделі.

# %%
def select_best_by_accuracy_time(results, lambda_weight=1.0, n_top=1):
    """
    Обирає оптимальні параметри, комбінуючи точність та час виконання, і відображає ТОП N найкращих.

    Parameters:
        results: Список результатів Grid Search (із ключами 'accuracy' і 'time_elapsed').
        lambda_weight: Вага часу у метриці: Score = Accuracy - lambda_weight * Time.
        n_top: Кількість найкращих параметрів, які потрібно повернути (за замовчуванням 1).

    Returns:
        top_results: ТОП N результатів із Grid Search, відсортовані у спадному порядку за 'score'.
    """
    # Обрахунок скорингу для кожного результату
    for result in results:
        result['score'] = result['accuracy'] - lambda_weight * result['time_elapsed']
    
    # Сортуємо список за значенням 'score' у спадному порядку
    sorted_results = sorted(results, key=lambda x: x['score'], reverse=True)
    
    # Повертаємо ТОП N результатів
    top_results = sorted_results[:n_top]

    # Виведення ТОП N результатів у форматі таблиці
    print(f"\nTop {n_top} Parameters that take to account time:")
    print(f"{'Rank':<5} {'n_estimators':<12} {'max_depth':<10} {'eta':<6} {'accuracy':<8} {'time(s)':<8}")
    for i, params in enumerate(top_results, start=1):
        print(f"{i:<5} {params['n_estimators']:<12} {params['max_depth']:<10} {params['eta']:<6.2f} "
              f"{params['accuracy']:<8.4f} {params['time_elapsed']:<8.2f}")
    
    return top_results

# %% [markdown]
# ### Візуалізація отриманих результатів
#
# Інколи візуалізація дозволяє отимати краще розуміння про задіяні параметри. Дана функція це спроба візуалізації точок на площині 'max_depth' та 'eta', яка показує значення accuracy. Візуалізація будується для кожного значення n_estimators окремо.

# %%
def plot_grid_results_3d_scatter_with_lines(grid_results, n_estimators_values):
    """
    Побудова 3D-розташування точок (scatter plot) для значень accuracy,
    та вертикальних ліній, що опускаються з точок на площину XY,
    для кожного значення n_estimators.

    Parameters:
        grid_results: Список результатів Grid Search (містить 'n_estimators', 'max_depth', 'eta', 'accuracy').
        n_estimators_values: Список значень n_estimators для окремих графіків.

    Returns:
        None
    """
    for n_estimators in n_estimators_values:
        # Фільтруємо результати для поточного n_estimators
        filtered_results = [res for res in grid_results if res['n_estimators'] == n_estimators]

        # Список значень для X, Y, Z
        eta_values = [res['eta'] for res in filtered_results]
        max_depth_values = [res['max_depth'] for res in filtered_results]
        accuracy_values = [res['accuracy'] for res in filtered_results]

        # Генеруємо кольори залежно від значень accuracy
        cmap = get_cmap('viridis')
        norm = plt.Normalize(min(accuracy_values), max(accuracy_values))
        colors = cmap(norm(accuracy_values))

        # Побудова 3D-графіка
        fig = plt.figure(figsize=(14, 8))
        ax = fig.add_subplot(111, projection='3d')

        # Побудова точок
        sc = ax.scatter(eta_values, max_depth_values, accuracy_values, c=colors, s=50, cmap='viridis', edgecolor='k')

        # Додавання вертикальних ліній до площини XY
        for x, y, z in zip(eta_values, max_depth_values, accuracy_values):
            ax.plot([x, x], [y, y], [0, z], color='black', linestyle='dashed', linewidth=0.7)

        # Налаштування осей
        ax.set_title(f"Accuracy for n_estimators={n_estimators}")
        ax.set_xlabel("eta (learning_rate)")
        ax.set_ylabel("max_depth")
        ax.set_zlabel("Accuracy")

        # Додаємо кольорову шкалу
        mappable = plt.cm.ScalarMappable(norm=norm, cmap=cmap)
        mappable.set_array(accuracy_values)
        fig.colorbar(mappable, ax=ax, shrink=0.6, aspect=8, label='Accuracy')

        # Показуємо графік
        plt.tight_layout()
        plt.show()

# %%
def extract_pixel_features_rgb_with_lbp_and_colors(image, coordinates, radius=1, n_points=8, method='uniform'):
    """
    Extract LBP features and RGB values for each pixel coordinate.
    
    Parameters:
        image: RGB input image.
        coordinates: List of pixel coordinates [(y1, x1), (y2, x2), ...].
        radius: Radius for the LBP descriptor.
        n_points: Number of sampling points for the LBP descriptor.
        method: LBP calculation method ('uniform', 'default', etc.).
    
    Returns:
        np.array: Feature vectors for each pixel.
    """
    features = []
    b_channel, g_channel, r_channel = cv2.split(image)

    for coord in coordinates:
        y, x = coord
        lbp_features = []
        for channel in [b_channel, g_channel, r_channel]:
            patch = channel[max(0, y - radius):min(channel.shape[0], y + radius + 1),
                            max(0, x - radius):min(channel.shape[1], x + radius + 1)]
            if patch.shape[0] < 2 * radius + 1 or patch.shape[1] < 2 * radius + 1:
                patch = cv2.resize(patch, (2 * radius + 1, 2 * radius + 1))
            lbp = local_binary_pattern(patch, P=n_points, R=radius, method=method)
            lbp_features.extend(lbp.flatten())

        rgb_values = [r_channel[y, x], g_channel[y, x], b_channel[y, x]]
        feature_vector = np.concatenate((lbp_features, rgb_values))
        features.append(feature_vector)

    return np.array(features)

# %% [markdown]
# ### Навчання моделі
#
# Використаємо стандартний підхід до навчання, коли навчальні дані розбиваються на дві частини: тренувальні дані та перевірочні дані.
# Навідміну від попереднього дослдіження LBP+Color+XGBoost per-pixel Sentinel дана функція здатна приймати більше параметрів на вхід, що дозволяє запустити цикл з різними параметрами для їх оцінки.

# %%
def train_xgboost_classifier(features, labels, n_estimators=300, max_depth=6, eta=0.3):
    """
    Train an XGBoost classifier.
    
    Parameters:
        features: Feature matrix (N x M, where M is the feature size).
        labels: Corresponding labels (N x 1).
    
    Returns:
        Trained XGBoost model.
    """
    X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.3, random_state=42)

    model = xgb.XGBClassifier(
        objective='multi:softmax',
        num_class=4,
        n_estimators=n_estimators,
        max_depth=max_depth,
        eta=eta
    )
    
    model.fit(X_train, y_train)
    
    # Evaluate model performance
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy: {accuracy * 100:.2f}%")
    print("Classification Report:")
    print(classification_report(y_test, y_pred))
    
    return model

# %% [markdown]
# ### Функція класифікація
#
# В даній функції реалізована можливість оцінки моделі на зображеннях відмінних від тих які використовувались для її навчання та перевірки.

# %%
def classify_entire_image(image, model, radius=1, n_points=8, class_to_color=None, expected_size=None, use_color=True, use_lbp=True):
    """
    Classify each pixel in the input image using the trained model with support for LBP, RGB, or LBP+RGB features.

    Parameters:
        image: Input RGB image.
        model: Trained XGBoost model or any compatible classifier.
        radius: Radius for the LBP descriptor.
        n_points: Number of sampling points for the LBP descriptor.
        class_to_color: Mapping of class indices to RGB colors.
        expected_size: Expected size of feature vectors for inference (must match training).
        use_color: Whether to include RGB color values in the feature vector (True to include RGB).
        use_lbp: Whether to include LBP features in the feature vector (True to include LBP).

    Returns:
        full_mask: Output classification mask (RGB image).
    """
    height, width = image.shape[:2]
    full_mask = np.zeros((height, width, 3), dtype=np.uint8)

    # Loop through each pixel and classify
    for y in range(height):
        for x in range(width):
            feature_vector = []  # This will store both LBP and/or RGB features based on settings

            # Extract LBP features if enabled
            if use_lbp:
                lbp_features = []
                for channel in cv2.split(image):
                    # Extract local patch around the pixel
                    patch = channel[max(0, y - radius):min(channel.shape[0], y + radius + 1),
                                    max(0, x - radius):min(channel.shape[1], x + radius + 1)]
                    if patch.shape[0] < 2 * radius + 1 or patch.shape[1] < 2 * radius + 1:
                        patch = cv2.resize(patch, (2 * radius + 1, 2 * radius + 1))
                    # Compute LBP for the local patch
                    lbp = local_binary_pattern(patch, P=n_points, R=radius, method='uniform')
                    lbp_features.extend(lbp.flatten())  # Append LBP features for the channel
                feature_vector.extend(lbp_features)  # Add LBP features to the feature vector

            # Extract color features if enabled
            if use_color:
                rgb_values = [image[y, x, 2], image[y, x, 1], image[y, x, 0]]  # RGB order
                feature_vector.extend(rgb_values)  # Add RGB values to the feature vector

            # Convert feature vector to np.array
            feature_vector = np.array(feature_vector)

            # Ensure feature vector size matches the expected size for the model
            if expected_size is None:
                # Retrieve the expected size from the model
                expected_size = len(model.feature_names_in_)
            if feature_vector.shape[0] != expected_size:
                if feature_vector.shape[0] < expected_size:
                    feature_vector = np.pad(feature_vector, (0, expected_size - feature_vector.shape[0]), mode='constant')
                elif feature_vector.shape[0] > expected_size:
                    feature_vector = feature_vector[:expected_size]  # Truncate features if too large

            # Run prediction for the pixel
            prediction = model.predict(np.array([feature_vector]))[0]
            # Map the prediction to the corresponding color
            full_mask[y, x] = class_to_color[prediction]

    return full_mask

# %% [markdown]
# ### Окрема функція для перевірки моделі
#
# Дана функція оцінює точність класифікація відповідно до наданої маски. Це надає можливість провести чистий експеремент коли дані яку були використані для тренування та перевірки моделі, та дані які будуть використовуватись для оцінки моделі відрізняються.

# %%
def evaluate_classification_results(resulting_mask, eval_mask, color_to_class):
    """
    Оцінює точність класифікації на основі повної маски для оцінки.

    Parameters:
        resulting_mask: Класифікована маска (BGR).
        eval_mask: Маска для оцінки точності (BGR).
        color_to_class: Словник, що встановлює відповідність кольорів класам.

    Returns:
        accuracy: Точність класифікації.
        report: Повний звіт класифікації.
    """
    eval_labels = []
    predicted_labels = []
    
    # Білий колір (зазвичай ігноровані пікселі)
    ignored_color = (255, 255, 255)  # Білий у форматі BGR

    # Проходимо через пікселі оцінкової маски
    for y in range(eval_mask.shape[0]):
        for x in range(eval_mask.shape[1]):
            eval_color = tuple(eval_mask[y, x])  # BGR формат
            predicted_color = tuple(resulting_mask[y, x])  # BGR формат

            # Ігнорувати пікселі білого кольору
            if eval_color == ignored_color:
                continue

            # Перевіряємо, чи кольори присутні в словнику для оцінки
            if eval_color in color_to_class:
                eval_labels.append(color_to_class[eval_color])
            else:
                print(f"Warning: eval_color {eval_color} не знайдено в color_to_class.")
                continue  # Пропускаємо, якщо eval_color немає в словнику
                
            if predicted_color in color_to_class:
                predicted_labels.append(color_to_class[predicted_color])
            else:
                print(f"Warning: predicted_color {predicted_color} не знайдено в color_to_class.")
                continue  # Пропускаємо, якщо predicted_color немає в словнику

    # Якщо після всіх перевірок немає пікселів для обчислення, повернемо нульові значення
    if len(eval_labels) == 0 or len(predicted_labels) == 0:
        print("Warning: У обраній області немає відповідних пікселів для оцінки.")
        return 0.0, "No data available for evaluation."

    # Використовуємо sklearn для оцінки точності
    accuracy = accuracy_score(eval_labels, predicted_labels)
    report = classification_report(eval_labels, predicted_labels, zero_division=0)
    
    return accuracy, report

# %% [markdown]
# ### Головна функція
#
# В даній функції використовується підхід (LBP + Color) + XGBoost та зображення Sentinel data. Функція застосовує Grid Search для перебору параметрів та знаходження найоптимальніших значень для XGBoost та LBP. В рамках дослідження проведемо оцінку оптимальної конфігурації беручи до уваги рекомендованя значення LBP та змінюючи лише конфігурацію XGBoost. А також порівняємо з результататми які отримаємо для  сітки яка буде вразовувати зміни не лише для XGBosst а  XGBoost + LBP.
#
# Оцінимо роботу на основі двох зображень Sentinel data (SS1 та SS2).

# %% [markdown]
# ### (LBP + Color) + XGBoost

# %%
if __name__ == "__main__":
    # Підрахунок часу для всього процесу
    total_start_time = time.perf_counter()

    # --- Обробка першого зображеня ---
    print("==================================")
    print("Evaluation SS1")
    print("==================================")
    process_start_time = time.perf_counter()
    
    # Шляхи до зображень   
    image_path = "Images/sentinel/SS1/SS1.bmp"
    eval_image_path = "Images/sentinel/SS1/SS1.bmp"  # Шумлене зображення
    
    # Шляхи до масок
    train_mask_path = "Images/sentinel/SS1/Samples1.bmp"  # Маска для тренування
    eval_mask_path = "Images/sentinel/SS1/Etalon1.bmp"  # Маска для оцінки точності класифікації (повна)
    
    # Завантажуємо зображення та маски
    rgb_image = cv2.imread(image_path, cv2.IMREAD_COLOR)
    eval_image = cv2.imread(eval_image_path, cv2.IMREAD_COLOR)  # Зашумлене зображення
    train_mask = cv2.imread(train_mask_path, cv2.IMREAD_COLOR)  # Маска для тренування
    eval_mask = cv2.imread(eval_mask_path, cv2.IMREAD_COLOR)  # Маска для тренування
    eval_mask_rgb = cv2.cvtColor(eval_mask, cv2.COLOR_BGR2RGB) # Маска для оцінки точності

    # Встановлюємо колір-клас відповідність:
    color_to_class = {
        (0, 0, 255): 0,    # Синій - Вода
        (0, 255, 0): 1,    # Зелений - Рослинність
        (0, 0, 0): 2,      # Чорний - Відкритий ґрунт
        (255, 255, 0): 3   # Жовтий - Урбанізація
    }

    class_to_color = {v: k for k, v in color_to_class.items()}  # Зворотня відповідність для класифікованого результату

    # === Тренування моделі ===
    sampled_coordinates, sampled_labels, training_mask = prepare_data_with_colored_mask(
        rgb_image, train_mask, color_to_class, pixel_sample_percentage=1.0
    )

    # # Візуалізуємо вибрану тренувальну маску
    # training_mask_rgb = cv2.cvtColor(training_mask, cv2.COLOR_BGR2RGB)  # Переводимо в RGB для matplotlib
    # plt.figure(figsize=(8, 8))
    # plt.imshow(training_mask_rgb)
    # plt.axis('off')
    # plt.title("Training Mask")
    # plt.show()
    # cv2.imwrite("Images/temp/training_mask.png", training_mask)  # Зберігаємо тренувальну маску для аналізу

    # LBP + RGB
    features = extract_pixel_features_rgb_with_lbp_and_colors(
        rgb_image, sampled_coordinates, radius=2, n_points=16
    )

    # --- Пошук найкращих параметрів ---
    # param_grid = {
    #     'n_estimators': [100, 200, 300, 500],  # Кількість дерев для навчання
    #     'max_depth': [4, 6, 8, 10, 12],        # Глибина дерев
    #     'eta': [0.01, 0.05, 0.1, 0.2, 0.3, 0.5] # Швидкість навчання
    # }
    param_grid = {
        'n_estimators': [100, 200, 300, 500],
        'max_depth': [4, 6, 8],
        'eta': [0.05, 0.1, 0.3]
    }

    best_params, top_5_params, grid_results = grid_search_xgboost(features, sampled_labels, param_grid)

    # # Значення n_estimators, для яких хочемо побудувати графіки
    # #n_estimators_values = param_grid['n_estimators']    
    # n_estimators_values = [100, 200, 300]
    
    # # Побудова точкових 3D-графіків
    # plot_grid_results_3d_scatter_with_lines(grid_results, n_estimators_values)
    
    # --- Вибір оптимальної комбінації точність/час ---
    lambda_weight = 0.1  # Регулювання впливу часу на вибір метрики (залежно від вимог задачі)
    optimal_results = select_best_by_accuracy_time(grid_results, lambda_weight=1.0, n_top=5)

    # Тренуємо модель XGBoost
    model = train_xgboost_classifier(
        features=features,
        labels=sampled_labels,
        n_estimators=best_params['n_estimators'],
        max_depth=best_params['max_depth'],
        eta=best_params['eta']
    )
       
    # === Класифікація первірочного зображення ===   

    # # Візуалізуємо вибрану перевірочну маску
    # plt.figure(figsize=(8, 8))
    # plt.imshow(eval_mask_rgb)
    # plt.axis('off')
    # plt.title("Eval Mask")
    # plt.show()
    # cv2.imwrite("Images/temp/eval_mask.png", training_mask)  # Зберігаємо тренувальну маску для аналізу
    
    eval_resulting_mask = classify_entire_image(
        eval_image, model, radius=2, n_points=16, class_to_color=class_to_color, expected_size=features.shape[1], use_color=True, use_lbp=True
    )
    eval_resulting_mask_rgb = cv2.cvtColor(eval_resulting_mask, cv2.COLOR_BGR2RGB)  # Формат RGB
    # plt.figure(figsize=(8, 8))
    # plt.imshow(eval_resulting_mask)
    # plt.axis('off')
    # plt.title("Resulting Mask with LBP (Eval Image)")
    # plt.show()
    # cv2.imwrite("Images/temp/eval_result_colored_mask_lbp.png", eval_resulting_mask_rgb)  # Зберігаємо результат
    
    # === Оцінка точності на основі повної маски ===
    eval_resulting_mask_bgr = cv2.cvtColor(eval_resulting_mask, cv2.COLOR_RGB2BGR)

    # Виведення унікальних кольорів у масці
    unique_colors_eval, counts_eval = np.unique(eval_mask.reshape(-1, 3), axis=0, return_counts=True)
    print("Unique colors in eval_mask (BGR):", dict(zip(map(tuple, unique_colors_eval), counts_eval)))
    
    eval_accuracy, eval_report = evaluate_classification_results(
        eval_resulting_mask, eval_mask_rgb, color_to_class
    )
    
    # Виведення результатів
    print(f"Evaluation Accuracy on Eval Image: {eval_accuracy * 100:.2f}%")
    print("Evaluation Classification Report:")
    print(eval_report)

    # Показуємо час для першого зображення
    process_end_time = time.perf_counter()
    print(f"Time taken for first image pair processing: {process_end_time - process_start_time:.2f} seconds")

    # --- Обробка другого зображеня ---
    print("==================================")
    print("Evaluation SS2")
    print("==================================")

        # Шляхи до зображень   
    image_path = "Images/sentinel/SS2/SS2.bmp"
    eval_image_path = "Images/sentinel/SS2/SS2.bmp"  # Шумлене зображення
    
    # Шляхи до масок
    train_mask_path = "Images/sentinel/SS2/Samples2.bmp"  # Маска для тренування
    eval_mask_path = "Images/sentinel/SS2/Etalon2.bmp"  # Маска для оцінки точності класифікації (повна)
    
    # Завантажуємо зображення та маски
    rgb_image = cv2.imread(image_path, cv2.IMREAD_COLOR)
    eval_image = cv2.imread(eval_image_path, cv2.IMREAD_COLOR)  # Зашумлене зображення
    train_mask = cv2.imread(train_mask_path, cv2.IMREAD_COLOR)  # Маска для тренування
    eval_mask = cv2.imread(eval_mask_path, cv2.IMREAD_COLOR)  # Маска для тренування
    eval_mask_rgb = cv2.cvtColor(eval_mask, cv2.COLOR_BGR2RGB) # Маска для оцінки точності

    # Встановлюємо колір-клас відповідність:
    color_to_class = {
        (0, 0, 255): 0,    # Синій - Вода
        (0, 255, 0): 1,    # Зелений - Рослинність
        (0, 0, 0): 2,      # Чорний - Відкритий ґрунт
        (255, 255, 0): 3   # Жовтий - Урбанізація
    }

    class_to_color = {v: k for k, v in color_to_class.items()}  # Зворотня відповідність для класифікованого результату

    # === Тренування моделі ===
    sampled_coordinates, sampled_labels, training_mask = prepare_data_with_colored_mask(
        rgb_image, train_mask, color_to_class, pixel_sample_percentage=1.0
    )

    # # Візуалізуємо вибрану тренувальну маску
    # training_mask_rgb = cv2.cvtColor(training_mask, cv2.COLOR_BGR2RGB)  # Переводимо в RGB для matplotlib
    # plt.figure(figsize=(8, 8))
    # plt.imshow(training_mask_rgb)
    # plt.axis('off')
    # plt.title("Training Mask")
    # plt.show()
    # cv2.imwrite("Images/temp/training_mask.png", training_mask)  # Зберігаємо тренувальну маску для аналізу

    # LBP + RGB
    features = extract_pixel_features_rgb_with_lbp_and_colors(
        rgb_image, sampled_coordinates, radius=2, n_points=16
    )

    # --- Пошук найкращих параметрів ---
    # param_grid = {
    #     'n_estimators': [100, 200, 300, 500],  # Кількість дерев для навчання
    #     'max_depth': [4, 6, 8, 10, 12],        # Глибина дерев
    #     'eta': [0.01, 0.05, 0.1, 0.2, 0.3, 0.5] # Швидкість навчання
    # }
    param_grid = {
        'n_estimators': [100, 200, 300, 500],
        'max_depth': [4, 6, 8],
        'eta': [0.05, 0.1, 0.3]
    }

    best_params, top_5_params, grid_results = grid_search_xgboost(features, sampled_labels, param_grid)

    # # Значення n_estimators, для яких хочемо побудувати графіки
    # #n_estimators_values = param_grid['n_estimators']    
    # n_estimators_values = [100, 200, 300]
    
    # # Побудова точкових 3D-графіків
    # plot_grid_results_3d_scatter_with_lines(grid_results, n_estimators_values)
    
    # --- Вибір оптимальної комбінації точність/час ---
    lambda_weight = 0.1  # Регулювання впливу часу на вибір метрики (залежно від вимог задачі)
    optimal_results = select_best_by_accuracy_time(grid_results, lambda_weight=1.0, n_top=5)

    # Тренуємо модель XGBoost
    model = train_xgboost_classifier(
        features=features,
        labels=sampled_labels,
        n_estimators=best_params['n_estimators'],
        max_depth=best_params['max_depth'],
        eta=best_params['eta']
    )
       
    # === Класифікація первірочного зображення ===   

    # # Візуалізуємо вибрану перевірочну маску
    # plt.figure(figsize=(8, 8))
    # plt.imshow(eval_mask_rgb)
    # plt.axis('off')
    # plt.title("Eval Mask")
    # plt.show()
    # cv2.imwrite("Images/temp/eval_mask.png", training_mask)  # Зберігаємо тренувальну маску для аналізу
    
    eval_resulting_mask = classify_entire_image(
        eval_image, model, radius=2, n_points=16, class_to_color=class_to_color, expected_size=features.shape[1], use_color=True, use_lbp=True
    )
    eval_resulting_mask_rgb = cv2.cvtColor(eval_resulting_mask, cv2.COLOR_BGR2RGB)  # Формат RGB
    # plt.figure(figsize=(8, 8))
    # plt.imshow(eval_resulting_mask)
    # plt.axis('off')
    # plt.title("Resulting Mask with LBP (Eval Image)")
    # plt.show()
    # cv2.imwrite("Images/temp/eval_result_colored_mask_lbp.png", eval_resulting_mask_rgb)  # Зберігаємо результат
    
    # === Оцінка точності на основі повної маски ===
    eval_resulting_mask_bgr = cv2.cvtColor(eval_resulting_mask, cv2.COLOR_RGB2BGR)

    # Виведення унікальних кольорів у масці
    unique_colors_eval, counts_eval = np.unique(eval_mask.reshape(-1, 3), axis=0, return_counts=True)
    print("Unique colors in eval_mask (BGR):", dict(zip(map(tuple, unique_colors_eval), counts_eval)))
    
    eval_accuracy, eval_report = evaluate_classification_results(
        eval_resulting_mask, eval_mask_rgb, color_to_class
    )
    
    # Виведення результатів
    print(f"Evaluation Accuracy on Eval Image: {eval_accuracy * 100:.2f}%")
    print("Evaluation Classification Report:")
    print(eval_report)

    # Підрахунок загального часу роботи програми
    total_end_time = time.perf_counter()
    print(f"Total time taken: {total_end_time - total_start_time:.2f} seconds")
# Out:
# ==================================
# Evaluation SS1
# ==================================
# Evaluated params: n_estimators=100, max_depth=4, eta=0.05, accuracy=0.9721, time_elapsed=1.16 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.1, accuracy=0.9768, time_elapsed=1.19 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.3, accuracy=0.9822, time_elapsed=1.21 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.05, accuracy=0.9776, time_elapsed=1.43 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.1, accuracy=0.9817, time_elapsed=1.53 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.3, accuracy=0.9842, time_elapsed=1.48 seconds
# Evaluated params: n_estimators=100, max_depth=8, eta=0.05, accuracy=0.9791, time_elapsed=1.78 seconds
# Evaluated params: n_estimators=100, max_depth=8, eta=0.1, accuracy=0.9822, time_elapsed=1.83 seconds
# Evaluated params: n_estimators=100, max_depth=8, eta=0.3, accuracy=0.9845, time_elapsed=1.91 seconds
# Evaluated params: n_estimators=200, max_depth=4, eta=0.05, accuracy=0.9771, time_elapsed=2.26 seconds
# Evaluated params: n_estimators=200, max_depth=4, eta=0.1, accuracy=0.9802, time_elapsed=2.50 seconds
# Evaluated params: n_estimators=200, max_depth=4, eta=0.3, accuracy=0.9836, time_elapsed=2.25 seconds
# Evaluated params: n_estimators=200, max_depth=6, eta=0.05, accuracy=0.9810, time_elapsed=2.92 seconds
# Evaluated params: n_estimators=200, max_depth=6, eta=0.1, accuracy=0.9839, time_elapsed=2.97 seconds
# Evaluated params: n_estimators=200, max_depth=6, eta=0.3, accuracy=0.9848, time_elapsed=3.02 seconds
# Evaluated params: n_estimators=200, max_depth=8, eta=0.05, accuracy=0.9826, time_elapsed=3.46 seconds
# Evaluated params: n_estimators=200, max_depth=8, eta=0.1, accuracy=0.9836, time_elapsed=3.73 seconds
# Evaluated params: n_estimators=200, max_depth=8, eta=0.3, accuracy=0.9855, time_elapsed=3.33 seconds
# Evaluated params: n_estimators=300, max_depth=4, eta=0.05, accuracy=0.9795, time_elapsed=3.52 seconds
# Evaluated params: n_estimators=300, max_depth=4, eta=0.1, accuracy=0.9822, time_elapsed=3.61 seconds
# Evaluated params: n_estimators=300, max_depth=4, eta=0.3, accuracy=0.9849, time_elapsed=3.51 seconds
# Evaluated params: n_estimators=300, max_depth=6, eta=0.05, accuracy=0.9831, time_elapsed=4.55 seconds
# Evaluated params: n_estimators=300, max_depth=6, eta=0.1, accuracy=0.9845, time_elapsed=4.46 seconds
# Evaluated params: n_estimators=300, max_depth=6, eta=0.3, accuracy=0.9848, time_elapsed=4.57 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.05, accuracy=0.9839, time_elapsed=5.50 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.1, accuracy=0.9842, time_elapsed=5.66 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.3, accuracy=0.9858, time_elapsed=4.98 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.05, accuracy=0.9818, time_elapsed=5.84 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.1, accuracy=0.9836, time_elapsed=6.14 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.3, accuracy=0.9850, time_elapsed=5.97 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.05, accuracy=0.9838, time_elapsed=8.15 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.1, accuracy=0.9852, time_elapsed=7.25 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.3, accuracy=0.9850, time_elapsed=6.96 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.05, accuracy=0.9841, time_elapsed=9.17 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.1, accuracy=0.9849, time_elapsed=8.78 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.3, accuracy=0.9860, time_elapsed=7.61 seconds
#
# Best Parameters: {'n_estimators': 500, 'max_depth': 8, 'eta': 0.3, 'accuracy': 0.986005039736383, 'time_elapsed': 7.606366124993656}
#
# Top 5 Parameters:
# Rank  n_estimators max_depth  eta    accuracy time(s)
# 1     500          8          0.30   0.9860   7.61
# 2     300          8          0.30   0.9858   4.98
# 3     200          8          0.30   0.9855   3.33
# 4     500          6          0.10   0.9852   7.25
# 5     500          6          0.30   0.9850   6.96
#
# Top 5 Parameters that take to account time:
# Rank  n_estimators max_depth  eta    accuracy time(s)
# 1     100          4          0.05   0.9721   1.16
# 2     100          4          0.10   0.9768   1.19
# 3     100          4          0.30   0.9822   1.21
# 4     100          6          0.05   0.9776   1.43
# 5     100          6          0.30   0.9842   1.48
# Accuracy: 98.60%
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     15754
#            1       0.98      0.99      0.98      5908
#            2       0.93      0.93      0.93      1932
#            3       0.95      0.94      0.94      2201
#
#     accuracy                           0.99     25795
#    macro avg       0.96      0.96      0.96     25795
# weighted avg       0.99      0.99      0.99     25795
#
# Unique colors in eval_mask (BGR): {(0, 0, 0): 7898, (0, 255, 0): 38258, (0, 255, 255): 12154, (255, 0, 0): 96852, (255, 255, 255): 106982}
# Evaluation Accuracy on Eval Image: 97.43%
# Evaluation Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99     96852
#            1       0.96      0.96      0.96     38258
#            2       0.88      0.93      0.90      7898
#            3       0.97      0.87      0.92     12154
#
#     accuracy                           0.97    155162
#    macro avg       0.95      0.94      0.94    155162
# weighted avg       0.97      0.97      0.97    155162
#
# Time taken for first image pair processing: 317.06 seconds
# ==================================
# Evaluation SS2
# ==================================
# Evaluated params: n_estimators=100, max_depth=4, eta=0.05, accuracy=0.9249, time_elapsed=0.76 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.1, accuracy=0.9436, time_elapsed=0.81 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.3, accuracy=0.9544, time_elapsed=0.78 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.05, accuracy=0.9394, time_elapsed=1.15 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.1, accuracy=0.9507, time_elapsed=1.22 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.3, accuracy=0.9546, time_elapsed=1.18 seconds
# Evaluated params: n_estimators=100, max_depth=8, eta=0.05, accuracy=0.9409, time_elapsed=1.53 seconds
# Evaluated params: n_estimators=100, max_depth=8, eta=0.1, accuracy=0.9491, time_elapsed=1.55 seconds
# Evaluated params: n_estimators=100, max_depth=8, eta=0.3, accuracy=0.9537, time_elapsed=1.59 seconds
# Evaluated params: n_estimators=200, max_depth=4, eta=0.05, accuracy=0.9425, time_elapsed=1.52 seconds
# Evaluated params: n_estimators=200, max_depth=4, eta=0.1, accuracy=0.9518, time_elapsed=1.56 seconds
# Evaluated params: n_estimators=200, max_depth=4, eta=0.3, accuracy=0.9567, time_elapsed=1.57 seconds
# Evaluated params: n_estimators=200, max_depth=6, eta=0.05, accuracy=0.9501, time_elapsed=2.22 seconds
# Evaluated params: n_estimators=200, max_depth=6, eta=0.1, accuracy=0.9532, time_elapsed=2.31 seconds
# Evaluated params: n_estimators=200, max_depth=6, eta=0.3, accuracy=0.9556, time_elapsed=2.22 seconds
# Evaluated params: n_estimators=200, max_depth=8, eta=0.05, accuracy=0.9495, time_elapsed=3.20 seconds
# Evaluated params: n_estimators=200, max_depth=8, eta=0.1, accuracy=0.9517, time_elapsed=3.05 seconds
# Evaluated params: n_estimators=200, max_depth=8, eta=0.3, accuracy=0.9548, time_elapsed=2.70 seconds
# Evaluated params: n_estimators=300, max_depth=4, eta=0.05, accuracy=0.9491, time_elapsed=2.33 seconds
# Evaluated params: n_estimators=300, max_depth=4, eta=0.1, accuracy=0.9541, time_elapsed=2.31 seconds
# Evaluated params: n_estimators=300, max_depth=4, eta=0.3, accuracy=0.9575, time_elapsed=2.31 seconds
# Evaluated params: n_estimators=300, max_depth=6, eta=0.05, accuracy=0.9522, time_elapsed=3.25 seconds
# Evaluated params: n_estimators=300, max_depth=6, eta=0.1, accuracy=0.9544, time_elapsed=3.24 seconds
# Evaluated params: n_estimators=300, max_depth=6, eta=0.3, accuracy=0.9561, time_elapsed=3.13 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.05, accuracy=0.9511, time_elapsed=4.69 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.1, accuracy=0.9521, time_elapsed=4.11 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.3, accuracy=0.9556, time_elapsed=3.53 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.05, accuracy=0.9531, time_elapsed=3.63 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.1, accuracy=0.9546, time_elapsed=3.62 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.3, accuracy=0.9578, time_elapsed=3.63 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.05, accuracy=0.9534, time_elapsed=5.22 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.1, accuracy=0.9556, time_elapsed=5.22 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.3, accuracy=0.9565, time_elapsed=4.76 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.05, accuracy=0.9529, time_elapsed=6.95 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.1, accuracy=0.9528, time_elapsed=6.54 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.3, accuracy=0.9562, time_elapsed=5.28 seconds
#
# Best Parameters: {'n_estimators': 500, 'max_depth': 4, 'eta': 0.3, 'accuracy': 0.9578193033381712, 'time_elapsed': 3.6282283749897033}
#
# Top 5 Parameters:
# Rank  n_estimators max_depth  eta    accuracy time(s)
# 1     500          4          0.30   0.9578   3.63
# 2     300          4          0.30   0.9575   2.31
# 3     200          4          0.30   0.9567   1.57
# 4     500          6          0.30   0.9565   4.76
# 5     500          8          0.30   0.9562   5.28
#
# Top 5 Parameters that take to account time:
# Rank  n_estimators max_depth  eta    accuracy time(s)
# 1     100          4          0.30   0.9544   0.78
# 2     100          4          0.05   0.9249   0.76
# 3     100          4          0.10   0.9436   0.81
# 4     100          6          0.05   0.9394   1.15
# 5     100          6          0.30   0.9546   1.18
# Accuracy: 95.78%
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      1268
#            1       0.92      0.93      0.92      1828
#            2       0.97      0.97      0.97      4501
#            3       0.96      0.95      0.96      3427
#
#     accuracy                           0.96     11024
#    macro avg       0.95      0.95      0.95     11024
# weighted avg       0.96      0.96      0.96     11024
#
# Unique colors in eval_mask (BGR): {(0, 0, 0): 19125, (0, 255, 0): 6032, (0, 255, 255): 28040, (255, 0, 0): 7117, (255, 255, 255): 201830}
# Evaluation Accuracy on Eval Image: 90.37%
# Evaluation Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.71      0.80      7117
#            1       0.60      0.98      0.74      6032
#            2       0.97      0.90      0.94     19125
#            3       0.97      0.94      0.95     28040
#
#     accuracy                           0.90     60314
#    macro avg       0.86      0.88      0.86     60314
# weighted avg       0.93      0.90      0.91     60314
#
# Total time taken: 573.83 seconds

# %% [markdown]
# ###  Аналіз отриманих значень
#
# З отриманих значень слідує що найоптимальнішою конфігурацією XGBoost з запропонованих параметрів для зображення SS1 являється наступна:
#
# Top 5 Parameters:
# Rank  n_estimators max_depth  eta    accuracy time(s)
# 1     500          8          0.30   0.9860   7.61
# 2     300          8          0.30   0.9858   4.98
# 3     200          8          0.30   0.9855   3.33
# 4     500          6          0.10   0.9852   7.25
# 5     500          6          0.30   0.9850   6.96
#
# Для SS2:
# Top 5 Parameters:
# Rank  n_estimators max_depth  eta    accuracy time(s)
# 1     500          4          0.30   0.9578   3.63
# 2     300          4          0.30   0.9575   2.31
# 3     200          4          0.30   0.9567   1.57
# 4     500          6          0.30   0.9565   4.76
# 5     500          8          0.30   0.9562   5.28
#
#
# В даному досліді не стоїть задача оптимзації моделі по часу, а лише пошук параметрів які покажуть найвищу точність.
#
# З отриманих значень можна зробити наступні висновки. Збільшення кількості дерев та глибини узагальному призводить до ускладнення обчислень та збільшення часу необхідного для підготовки моделі. Модель показала найкращі результати при високих значеннях n_estimators та max_depth. При цьому зменшення швидкості навчання, тобто eta - незначно погіршило результати.

# %% [markdown]
# ### Оновлена функція Grid Search
#
# Дана функція дозволяє враховувати додатково конфігурацію LBP.

# %%
def grid_search_xgboost(labels, param_grid, rgb_image, sampled_coordinates):
    """
    Виконує Grid Search для підбору оптимальних параметрів XGBoost, включаючи параметри 'radius' та 'n_points',
    для функції extract_pixel_features_rgb_with_lbp_and_colors.

    Parameters:
        labels: Відповідні класи для ознак.
        param_grid: Словник параметрів для Grid Search:
            {
                'n_estimators': [100, 200, 300],
                'max_depth': [4, 6, 8],
                'eta': [0.05, 0.1, 0.3],
                'radius': [1, 2, 3],
                'n_points': [8, 16, 24]
            }
        rgb_image: Вхідне RGB-зображення.
        sampled_coordinates: Координати пікселів для витягу ознак.

    Returns:
        best_params: Найкращі параметри після Grid Search.
        top_params: ТОП-5 найкращих параметрів (з найбільшим accuracy).
        results: Результати для всіх комбінацій параметрів.
    """
    from sklearn.model_selection import train_test_split
    from sklearn.metrics import accuracy_score
    import xgboost as xgb
    import time

    results = []  # Список для результатів (accuracy та час для кожної комбінації)

    # Перебір усіх комбінацій параметрів
    for n_estimators in param_grid['n_estimators']:
        for max_depth in param_grid['max_depth']:
            for eta in param_grid['eta']:
                for radius in param_grid['radius']:
                    for n_points in param_grid['n_points']:
                        start_time = time.perf_counter()  # Відлік часу для цієї комбінації

                        # === Витягуємо ознаки з новими параметрами radius і n_points ===
                        features = extract_pixel_features_rgb_with_lbp_and_colors(
                            rgb_image, sampled_coordinates, radius=radius, n_points=n_points
                        )

                        # Розбиваємо дані на тренувальні й тестові
                        X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.3, random_state=42)

                        # Ініціалізація моделі з поточними параметрами
                        model = xgb.XGBClassifier(
                            objective='multi:softmax',
                            num_class=4,
                            n_estimators=n_estimators,
                            max_depth=max_depth,
                            eta=eta
                        )
                        
                        # Навчання моделі
                        model.fit(X_train, y_train)
                        
                        # Передбачення тестових даних
                        y_pred = model.predict(X_test)
                        
                        # Оцінка точності
                        accuracy = accuracy_score(y_test, y_pred)
                        
                        # Обрахунок часу виконання
                        elapsed_time = time.perf_counter() - start_time
                        
                        # Збереження результату
                        results.append({
                            'n_estimators': n_estimators,
                            'max_depth': max_depth,
                            'eta': float(eta),  # Перетворюємо eta в float
                            'radius': radius,    # Додаємо radius
                            'n_points': n_points, # Додаємо n_points
                            'accuracy': float(accuracy),  # Перетворюємо accuracy в float
                            'time_elapsed': elapsed_time  # Час виконання в секундах
                        })
                        print(f"Evaluated params: n_estimators={n_estimators}, max_depth={max_depth}, eta={eta}, "
                              f"radius={radius}, n_points={n_points}, accuracy={accuracy:.4f}, time_elapsed={elapsed_time:.2f} seconds")

    # Сортуємо список результатів за значенням 'accuracy' (у спадному порядку)
    sorted_results = sorted(results, key=lambda x: x['accuracy'], reverse=True)

    # Пошук найкращих параметрів за accuracy
    best_params = sorted_results[0]

    # Топ-5 найкращих параметрів за accuracy
    top_params = sorted_results[:10]
    
    # Виведення найкращих параметрів
    print(f"\nBest Parameters: {best_params}")

    # Виведення ТОП-5 параметрів у зручному форматі
    print("\nTop 5 Parameters:")
    print(f"{'Rank':<5} {'n_estimators':<12} {'max_depth':<10} {'eta':<6} {'radius':<8} {'n_points':<10} {'accuracy':<8} {'time(s)':<8}")
    for i, params in enumerate(top_params, start=1):
        print(f"{i:<5} {params['n_estimators']:<12} {params['max_depth']:<10} {params['eta']:<6.2f} "
              f"{params['radius']:<8} {params['n_points']:<10} {params['accuracy']:<8.4f} {params['time_elapsed']:<8.2f}")

    return best_params, top_params, results

# %% [markdown]
# ### Головна функція комплексного підбору
#
# Дана функція дозволяє отримати значення точності класифікації для різних конфігурація XGBoost та LBP.

# %%
if __name__ == "__main__":
    # Підрахунок часу для всього процесу
    total_start_time = time.perf_counter()

    # --- Обробка першого зображеня ---
    print("==================================")
    print("Evaluation SS1")
    print("==================================")
    process_start_time = time.perf_counter()
    
    # Шляхи до зображень   
    image_path = "Images/sentinel/SS1/SS1.bmp"
    eval_image_path = "Images/sentinel/SS1/SS1.bmp"  # Шумлене зображення
    
    # Шляхи до масок
    train_mask_path = "Images/sentinel/SS1/Samples1.bmp"  # Маска для тренування
    eval_mask_path = "Images/sentinel/SS1/Etalon1.bmp"  # Маска для оцінки точності класифікації (повна)
    
    # Завантажуємо зображення та маски
    rgb_image = cv2.imread(image_path, cv2.IMREAD_COLOR)
    eval_image = cv2.imread(eval_image_path, cv2.IMREAD_COLOR)  # Зашумлене зображення
    train_mask = cv2.imread(train_mask_path, cv2.IMREAD_COLOR)  # Маска для тренування
    eval_mask = cv2.imread(eval_mask_path, cv2.IMREAD_COLOR)  # Маска для тренування
    eval_mask_rgb = cv2.cvtColor(eval_mask, cv2.COLOR_BGR2RGB) # Маска для оцінки точності

    # Встановлюємо колір-клас відповідність:
    color_to_class = {
        (0, 0, 255): 0,    # Синій - Вода
        (0, 255, 0): 1,    # Зелений - Рослинність
        (0, 0, 0): 2,      # Чорний - Відкритий ґрунт
        (255, 255, 0): 3   # Жовтий - Урбанізація
    }

    class_to_color = {v: k for k, v in color_to_class.items()}  # Зворотня відповідність для класифікованого результату

    # === Тренування моделі ===
    sampled_coordinates, sampled_labels, training_mask = prepare_data_with_colored_mask(
        rgb_image, train_mask, color_to_class, pixel_sample_percentage=1.0
    )

    # # Візуалізуємо вибрану тренувальну маску
    # training_mask_rgb = cv2.cvtColor(training_mask, cv2.COLOR_BGR2RGB)  # Переводимо в RGB для matplotlib
    # plt.figure(figsize=(8, 8))
    # plt.imshow(training_mask_rgb)
    # plt.axis('off')
    # plt.title("Training Mask")
    # plt.show()
    # cv2.imwrite("Images/temp/training_mask.png", training_mask)  # Зберігаємо тренувальну маску для аналізу

    # # LBP + RGB
    # features = extract_pixel_features_rgb_with_lbp_and_colors(
    #     rgb_image, sampled_coordinates, radius=2, n_points=16
    # )

    # --- Пошук найкращих параметрів ---
    # param_grid = {
    #     'n_estimators': [100, 200, 300, 500],  # Кількість дерев для навчання
    #     'max_depth': [4, 6, 8, 10, 12],        # Глибина дерев
    #     'eta': [0.01, 0.05, 0.1, 0.2, 0.3, 0.5] # Швидкість навчання
    # }
    param_grid = {
            'n_estimators': [100, 200, 300, 500],
            'max_depth': [4, 6, 8],
            'eta': [0.05, 0.1, 0.3],
            'radius': [1, 2, 3],
            'n_points': [8, 16, 24]
    }
    
    # param_grid = {
    #         'n_estimators': [100],
    #         'max_depth': [4, 6],
    #         'eta': [0.05, 0.1],
    #         'radius': [1, 2],
    #         'n_points': [8, 16]
    # }

    best_params, top_5_params, grid_results = grid_search_xgboost(sampled_labels, param_grid, rgb_image, sampled_coordinates)

    # # Значення n_estimators, для яких хочемо побудувати графіки
    # #n_estimators_values = param_grid['n_estimators']    
    # n_estimators_values = [100, 200, 300]
    
    # # Побудова точкових 3D-графіків
    # plot_grid_results_3d_scatter_with_lines(grid_results, n_estimators_values)
    
    # --- Вибір оптимальної комбінації точність/час ---
    lambda_weight = 0.1  # Регулювання впливу часу на вибір метрики (залежно від вимог задачі)
    optimal_results = select_best_by_accuracy_time(grid_results, lambda_weight=1.0, n_top=10)
    
    # LBP + RGB
    # Витягуємо ознаки за обраними параметрами `radius` та `n_points`
    features = extract_pixel_features_rgb_with_lbp_and_colors(
        rgb_image, sampled_coordinates,
        radius=best_params['radius'],
        n_points=best_params['n_points']
    )

    # Тренуємо модель XGBoost
    model = train_xgboost_classifier(
        features=features,
        labels=sampled_labels,
        n_estimators=best_params['n_estimators'],
        max_depth=best_params['max_depth'],
        eta=best_params['eta']
    )
       
    # === Класифікація первірочного зображення ===   

    # # Візуалізуємо вибрану перевірочну маску
    # plt.figure(figsize=(8, 8))
    # plt.imshow(eval_mask_rgb)
    # plt.axis('off')
    # plt.title("Eval Mask")
    # plt.show()
    # cv2.imwrite("Images/temp/eval_mask.png", training_mask)  # Зберігаємо тренувальну маску для аналізу

    print(f"Value for radius is ${best_params['radius']}")
    print(f"Value for radius is ${best_params['n_points']}")
    
    eval_resulting_mask = classify_entire_image(
        eval_image, model, radius=best_params['radius'], n_points=best_params['n_points'], class_to_color=class_to_color, expected_size=features.shape[1], use_color=True, use_lbp=True
    )
    eval_resulting_mask_rgb = cv2.cvtColor(eval_resulting_mask, cv2.COLOR_BGR2RGB)  # Формат RGB
    # plt.figure(figsize=(8, 8))
    # plt.imshow(eval_resulting_mask)
    # plt.axis('off')
    # plt.title("Resulting Mask with LBP (Eval Image)")
    # plt.show()
    # cv2.imwrite("Images/temp/eval_result_colored_mask_lbp.png", eval_resulting_mask_rgb)  # Зберігаємо результат
    
    # === Оцінка точності на основі повної маски ===
    eval_resulting_mask_bgr = cv2.cvtColor(eval_resulting_mask, cv2.COLOR_RGB2BGR)

    # Виведення унікальних кольорів у масці
    unique_colors_eval, counts_eval = np.unique(eval_mask.reshape(-1, 3), axis=0, return_counts=True)
    print("Unique colors in eval_mask (BGR):", dict(zip(map(tuple, unique_colors_eval), counts_eval)))
    
    eval_accuracy, eval_report = evaluate_classification_results(
        eval_resulting_mask, eval_mask_rgb, color_to_class
    )
    
    # Виведення результатів
    print(f"Evaluation Accuracy on Eval Image: {eval_accuracy * 100:.2f}%")
    print("Evaluation Classification Report:")
    print(eval_report)

    # Показуємо час для першого зображення
    process_end_time = time.perf_counter()
    print(f"Time taken for first image pair processing: {process_end_time - process_start_time:.2f} seconds")

    # --- Обробка другого зображеня ---
    print("==================================")
    print("Evaluation SS2")
    print("==================================")

        # Шляхи до зображень   
    image_path = "Images/sentinel/SS2/SS2.bmp"
    eval_image_path = "Images/sentinel/SS2/SS2.bmp"  # Шумлене зображення
    
    # Шляхи до масок
    train_mask_path = "Images/sentinel/SS2/Samples2.bmp"  # Маска для тренування
    eval_mask_path = "Images/sentinel/SS2/Etalon2.bmp"  # Маска для оцінки точності класифікації (повна)
    
    # Завантажуємо зображення та маски
    rgb_image = cv2.imread(image_path, cv2.IMREAD_COLOR)
    eval_image = cv2.imread(eval_image_path, cv2.IMREAD_COLOR)  # Зашумлене зображення
    train_mask = cv2.imread(train_mask_path, cv2.IMREAD_COLOR)  # Маска для тренування
    eval_mask = cv2.imread(eval_mask_path, cv2.IMREAD_COLOR)  # Маска для тренування
    eval_mask_rgb = cv2.cvtColor(eval_mask, cv2.COLOR_BGR2RGB) # Маска для оцінки точності

    # Встановлюємо колір-клас відповідність:
    color_to_class = {
        (0, 0, 255): 0,    # Синій - Вода
        (0, 255, 0): 1,    # Зелений - Рослинність
        (0, 0, 0): 2,      # Чорний - Відкритий ґрунт
        (255, 255, 0): 3   # Жовтий - Урбанізація
    }

    class_to_color = {v: k for k, v in color_to_class.items()}  # Зворотня відповідність для класифікованого результату

    # === Тренування моделі ===
    sampled_coordinates, sampled_labels, training_mask = prepare_data_with_colored_mask(
        rgb_image, train_mask, color_to_class, pixel_sample_percentage=1.0
    )

    # # Візуалізуємо вибрану тренувальну маску
    # training_mask_rgb = cv2.cvtColor(training_mask, cv2.COLOR_BGR2RGB)  # Переводимо в RGB для matplotlib
    # plt.figure(figsize=(8, 8))
    # plt.imshow(training_mask_rgb)
    # plt.axis('off')
    # plt.title("Training Mask")
    # plt.show()
    # cv2.imwrite("Images/temp/training_mask.png", training_mask)  # Зберігаємо тренувальну маску для аналізу

    # # LBP + RGB
    # features = extract_pixel_features_rgb_with_lbp_and_colors(
    #     rgb_image, sampled_coordinates, radius=2, n_points=16
    # )

    # --- Пошук найкращих параметрів ---
    # param_grid = {
    #     'n_estimators': [100, 200, 300, 500],  # Кількість дерев для навчання
    #     'max_depth': [4, 6, 8, 10, 12],        # Глибина дерев
    #     'eta': [0.01, 0.05, 0.1, 0.2, 0.3, 0.5] # Швидкість навчання
    # }
    # param_grid = {
    #         'n_estimators': [100],
    #         'max_depth': [4, 6],
    #         'eta': [0.05, 0.1],
    #         'radius': [1, 2],
    #         'n_points': [8, 16]
    # }
    param_grid = {
            'n_estimators': [100, 200, 300, 500],
            'max_depth': [4, 6, 8],
            'eta': [0.05, 0.1, 0.3],
            'radius': [1, 2, 3],
            'n_points': [8, 16, 24]
    }

    # best_params, top_5_params, grid_results = grid_search_xgboost(features, sampled_labels, param_grid)
    best_params, top_5_params, grid_results = grid_search_xgboost(sampled_labels, param_grid, rgb_image, sampled_coordinates)

    # # Значення n_estimators, для яких хочемо побудувати графіки
    # #n_estimators_values = param_grid['n_estimators']    
    # n_estimators_values = [100, 200, 300]
    
    # # Побудова точкових 3D-графіків
    # plot_grid_results_3d_scatter_with_lines(grid_results, n_estimators_values)
    
    # --- Вибір оптимальної комбінації точність/час ---
    lambda_weight = 0.1  # Регулювання впливу часу на вибір метрики (залежно від вимог задачі)
    optimal_results = select_best_by_accuracy_time(grid_results, lambda_weight=1.0, n_top=10)

        # LBP + RGB
    # Витягуємо ознаки за обраними параметрами `radius` та `n_points`
    features = extract_pixel_features_rgb_with_lbp_and_colors(
        rgb_image, sampled_coordinates,
        radius=best_params['radius'],
        n_points=best_params['n_points']
    )

    # Тренуємо модель XGBoost
    model = train_xgboost_classifier(
        features=features,
        labels=sampled_labels,
        n_estimators=best_params['n_estimators'],
        max_depth=best_params['max_depth'],
        eta=best_params['eta']
    )
       
    # === Класифікація первірочного зображення ===   

    # # Візуалізуємо вибрану перевірочну маску
    # plt.figure(figsize=(8, 8))
    # plt.imshow(eval_mask_rgb)
    # plt.axis('off')
    # plt.title("Eval Mask")
    # plt.show()
    # cv2.imwrite("Images/temp/eval_mask.png", training_mask)  # Зберігаємо тренувальну маску для аналізу

    print(f"Value for radius is ${best_params['radius']}")
    print(f"Value for radius is ${best_params['n_points']}")
    
    eval_resulting_mask = classify_entire_image(
        eval_image, model, radius=best_params['radius'], n_points=best_params['n_points'], class_to_color=class_to_color, expected_size=features.shape[1], use_color=True, use_lbp=True
    )
    eval_resulting_mask_rgb = cv2.cvtColor(eval_resulting_mask, cv2.COLOR_BGR2RGB)  # Формат RGB
    # plt.figure(figsize=(8, 8))
    # plt.imshow(eval_resulting_mask)
    # plt.axis('off')
    # plt.title("Resulting Mask with LBP (Eval Image)")
    # plt.show()
    # cv2.imwrite("Images/temp/eval_result_colored_mask_lbp.png", eval_resulting_mask_rgb)  # Зберігаємо результат
    
    # === Оцінка точності на основі повної маски ===
    eval_resulting_mask_bgr = cv2.cvtColor(eval_resulting_mask, cv2.COLOR_RGB2BGR)

    # Виведення унікальних кольорів у масці
    unique_colors_eval, counts_eval = np.unique(eval_mask.reshape(-1, 3), axis=0, return_counts=True)
    print("Unique colors in eval_mask (BGR):", dict(zip(map(tuple, unique_colors_eval), counts_eval)))
    
    eval_accuracy, eval_report = evaluate_classification_results(
        eval_resulting_mask, eval_mask_rgb, color_to_class
    )
    
    # Виведення результатів
    print(f"Evaluation Accuracy on Eval Image: {eval_accuracy * 100:.2f}%")
    print("Evaluation Classification Report:")
    print(eval_report)

    # Підрахунок загального часу роботи програми
    total_end_time = time.perf_counter()
    print(f"Total time taken: {total_end_time - total_start_time:.2f} seconds")
# Out:
# ==================================
# Evaluation SS1
# ==================================
# Evaluated params: n_estimators=100, max_depth=4, eta=0.05, radius=1, n_points=8, accuracy=0.9677, time_elapsed=6.11 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.05, radius=1, n_points=16, accuracy=0.9695, time_elapsed=6.21 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.05, radius=1, n_points=24, accuracy=0.9706, time_elapsed=6.34 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.05, radius=2, n_points=8, accuracy=0.9701, time_elapsed=6.91 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.05, radius=2, n_points=16, accuracy=0.9707, time_elapsed=7.22 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.05, radius=2, n_points=24, accuracy=0.9708, time_elapsed=7.50 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.05, radius=3, n_points=8, accuracy=0.9720, time_elapsed=8.22 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.05, radius=3, n_points=16, accuracy=0.9728, time_elapsed=8.49 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.05, radius=3, n_points=24, accuracy=0.9717, time_elapsed=9.11 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.1, radius=1, n_points=8, accuracy=0.9719, time_elapsed=6.28 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.1, radius=1, n_points=16, accuracy=0.9738, time_elapsed=6.38 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.1, radius=1, n_points=24, accuracy=0.9734, time_elapsed=6.48 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.1, radius=2, n_points=8, accuracy=0.9751, time_elapsed=7.08 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.1, radius=2, n_points=16, accuracy=0.9757, time_elapsed=7.23 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.1, radius=2, n_points=24, accuracy=0.9763, time_elapsed=7.60 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.1, radius=3, n_points=8, accuracy=0.9790, time_elapsed=7.94 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.1, radius=3, n_points=16, accuracy=0.9797, time_elapsed=8.42 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.1, radius=3, n_points=24, accuracy=0.9793, time_elapsed=8.96 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.3, radius=1, n_points=8, accuracy=0.9753, time_elapsed=6.15 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.3, radius=1, n_points=16, accuracy=0.9765, time_elapsed=6.23 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.3, radius=1, n_points=24, accuracy=0.9766, time_elapsed=6.38 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.3, radius=2, n_points=8, accuracy=0.9806, time_elapsed=6.92 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.3, radius=2, n_points=16, accuracy=0.9810, time_elapsed=7.21 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.3, radius=2, n_points=24, accuracy=0.9809, time_elapsed=7.57 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.3, radius=3, n_points=8, accuracy=0.9849, time_elapsed=8.06 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.3, radius=3, n_points=16, accuracy=0.9862, time_elapsed=8.57 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.3, radius=3, n_points=24, accuracy=0.9858, time_elapsed=9.19 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.05, radius=1, n_points=8, accuracy=0.9724, time_elapsed=6.44 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.05, radius=1, n_points=16, accuracy=0.9734, time_elapsed=6.67 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.05, radius=1, n_points=24, accuracy=0.9736, time_elapsed=6.85 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.05, radius=2, n_points=8, accuracy=0.9749, time_elapsed=7.27 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.05, radius=2, n_points=16, accuracy=0.9752, time_elapsed=7.59 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.05, radius=2, n_points=24, accuracy=0.9757, time_elapsed=7.82 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.05, radius=3, n_points=8, accuracy=0.9793, time_elapsed=8.28 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.05, radius=3, n_points=16, accuracy=0.9797, time_elapsed=8.73 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.05, radius=3, n_points=24, accuracy=0.9795, time_elapsed=9.10 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.1, radius=1, n_points=8, accuracy=0.9743, time_elapsed=6.27 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.1, radius=1, n_points=16, accuracy=0.9758, time_elapsed=6.43 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.1, radius=1, n_points=24, accuracy=0.9761, time_elapsed=6.43 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.1, radius=2, n_points=8, accuracy=0.9783, time_elapsed=7.17 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.1, radius=2, n_points=16, accuracy=0.9791, time_elapsed=7.46 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.1, radius=2, n_points=24, accuracy=0.9795, time_elapsed=7.99 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.1, radius=3, n_points=8, accuracy=0.9838, time_elapsed=8.12 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.1, radius=3, n_points=16, accuracy=0.9834, time_elapsed=9.02 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.1, radius=3, n_points=24, accuracy=0.9833, time_elapsed=9.17 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.3, radius=1, n_points=8, accuracy=0.9753, time_elapsed=6.24 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.3, radius=1, n_points=16, accuracy=0.9778, time_elapsed=6.49 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.3, radius=1, n_points=24, accuracy=0.9777, time_elapsed=6.59 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.3, radius=2, n_points=8, accuracy=0.9816, time_elapsed=7.09 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.3, radius=2, n_points=16, accuracy=0.9818, time_elapsed=7.42 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.3, radius=2, n_points=24, accuracy=0.9818, time_elapsed=7.70 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.3, radius=3, n_points=8, accuracy=0.9877, time_elapsed=8.04 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.3, radius=3, n_points=16, accuracy=0.9872, time_elapsed=8.74 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.3, radius=3, n_points=24, accuracy=0.9876, time_elapsed=9.49 seconds
# Evaluated params: n_estimators=100, max_depth=8, eta=0.05, radius=1, n_points=8, accuracy=0.9737, time_elapsed=6.46 seconds
# Evaluated params: n_estimators=100, max_depth=8, eta=0.05, radius=1, n_points=16, accuracy=0.9742, time_elapsed=6.60 seconds
# Evaluated params: n_estimators=100, max_depth=8, eta=0.05, radius=1, n_points=24, accuracy=0.9751, time_elapsed=6.70 seconds
# Evaluated params: n_estimators=100, max_depth=8, eta=0.05, radius=2, n_points=8, accuracy=0.9770, time_elapsed=7.25 seconds
# Evaluated params: n_estimators=100, max_depth=8, eta=0.05, radius=2, n_points=16, accuracy=0.9776, time_elapsed=7.58 seconds
# Evaluated params: n_estimators=100, max_depth=8, eta=0.05, radius=2, n_points=24, accuracy=0.9772, time_elapsed=8.14 seconds
# Evaluated params: n_estimators=100, max_depth=8, eta=0.05, radius=3, n_points=8, accuracy=0.9826, time_elapsed=8.54 seconds
# Evaluated params: n_estimators=100, max_depth=8, eta=0.05, radius=3, n_points=16, accuracy=0.9826, time_elapsed=9.11 seconds
# Evaluated params: n_estimators=100, max_depth=8, eta=0.05, radius=3, n_points=24, accuracy=0.9812, time_elapsed=9.60 seconds
# Evaluated params: n_estimators=100, max_depth=8, eta=0.1, radius=1, n_points=8, accuracy=0.9750, time_elapsed=6.41 seconds
# Evaluated params: n_estimators=100, max_depth=8, eta=0.1, radius=1, n_points=16, accuracy=0.9758, time_elapsed=6.73 seconds
# Evaluated params: n_estimators=100, max_depth=8, eta=0.1, radius=1, n_points=24, accuracy=0.9774, time_elapsed=6.80 seconds
# Evaluated params: n_estimators=100, max_depth=8, eta=0.1, radius=2, n_points=8, accuracy=0.9793, time_elapsed=7.29 seconds
# Evaluated params: n_estimators=100, max_depth=8, eta=0.1, radius=2, n_points=16, accuracy=0.9803, time_elapsed=7.84 seconds
# Evaluated params: n_estimators=100, max_depth=8, eta=0.1, radius=2, n_points=24, accuracy=0.9806, time_elapsed=7.86 seconds
# Evaluated params: n_estimators=100, max_depth=8, eta=0.1, radius=3, n_points=8, accuracy=0.9854, time_elapsed=8.51 seconds
# Evaluated params: n_estimators=100, max_depth=8, eta=0.1, radius=3, n_points=16, accuracy=0.9855, time_elapsed=9.02 seconds
# Evaluated params: n_estimators=100, max_depth=8, eta=0.1, radius=3, n_points=24, accuracy=0.9851, time_elapsed=9.61 seconds
# Evaluated params: n_estimators=100, max_depth=8, eta=0.3, radius=1, n_points=8, accuracy=0.9757, time_elapsed=6.49 seconds
# Evaluated params: n_estimators=100, max_depth=8, eta=0.3, radius=1, n_points=16, accuracy=0.9771, time_elapsed=6.71 seconds
# Evaluated params: n_estimators=100, max_depth=8, eta=0.3, radius=1, n_points=24, accuracy=0.9781, time_elapsed=6.89 seconds
# Evaluated params: n_estimators=100, max_depth=8, eta=0.3, radius=2, n_points=8, accuracy=0.9812, time_elapsed=7.47 seconds
# Evaluated params: n_estimators=100, max_depth=8, eta=0.3, radius=2, n_points=16, accuracy=0.9824, time_elapsed=7.56 seconds
# Evaluated params: n_estimators=100, max_depth=8, eta=0.3, radius=2, n_points=24, accuracy=0.9824, time_elapsed=7.97 seconds
# Evaluated params: n_estimators=100, max_depth=8, eta=0.3, radius=3, n_points=8, accuracy=0.9871, time_elapsed=8.49 seconds
# Evaluated params: n_estimators=100, max_depth=8, eta=0.3, radius=3, n_points=16, accuracy=0.9878, time_elapsed=9.09 seconds
# Evaluated params: n_estimators=100, max_depth=8, eta=0.3, radius=3, n_points=24, accuracy=0.9873, time_elapsed=9.57 seconds
# Evaluated params: n_estimators=200, max_depth=4, eta=0.05, radius=1, n_points=8, accuracy=0.9717, time_elapsed=6.75 seconds
# Evaluated params: n_estimators=200, max_depth=4, eta=0.05, radius=1, n_points=16, accuracy=0.9735, time_elapsed=6.94 seconds
# Evaluated params: n_estimators=200, max_depth=4, eta=0.05, radius=1, n_points=24, accuracy=0.9736, time_elapsed=7.14 seconds
# Evaluated params: n_estimators=200, max_depth=4, eta=0.05, radius=2, n_points=8, accuracy=0.9750, time_elapsed=7.77 seconds
# Evaluated params: n_estimators=200, max_depth=4, eta=0.05, radius=2, n_points=16, accuracy=0.9756, time_elapsed=8.00 seconds
# Evaluated params: n_estimators=200, max_depth=4, eta=0.05, radius=2, n_points=24, accuracy=0.9763, time_elapsed=8.61 seconds
# Evaluated params: n_estimators=200, max_depth=4, eta=0.05, radius=3, n_points=8, accuracy=0.9794, time_elapsed=9.05 seconds
# Evaluated params: n_estimators=200, max_depth=4, eta=0.05, radius=3, n_points=16, accuracy=0.9796, time_elapsed=9.56 seconds
# Evaluated params: n_estimators=200, max_depth=4, eta=0.05, radius=3, n_points=24, accuracy=0.9794, time_elapsed=10.34 seconds
# Evaluated params: n_estimators=200, max_depth=4, eta=0.1, radius=1, n_points=8, accuracy=0.9741, time_elapsed=6.78 seconds
# Evaluated params: n_estimators=200, max_depth=4, eta=0.1, radius=1, n_points=16, accuracy=0.9759, time_elapsed=7.03 seconds
# Evaluated params: n_estimators=200, max_depth=4, eta=0.1, radius=1, n_points=24, accuracy=0.9768, time_elapsed=7.18 seconds
# Evaluated params: n_estimators=200, max_depth=4, eta=0.1, radius=2, n_points=8, accuracy=0.9791, time_elapsed=7.97 seconds
# Evaluated params: n_estimators=200, max_depth=4, eta=0.1, radius=2, n_points=16, accuracy=0.9795, time_elapsed=8.04 seconds
# Evaluated params: n_estimators=200, max_depth=4, eta=0.1, radius=2, n_points=24, accuracy=0.9800, time_elapsed=8.27 seconds
# Evaluated params: n_estimators=200, max_depth=4, eta=0.1, radius=3, n_points=8, accuracy=0.9842, time_elapsed=9.10 seconds
# Evaluated params: n_estimators=200, max_depth=4, eta=0.1, radius=3, n_points=16, accuracy=0.9843, time_elapsed=10.45 seconds
# Evaluated params: n_estimators=200, max_depth=4, eta=0.1, radius=3, n_points=24, accuracy=0.9840, time_elapsed=10.33 seconds
# Evaluated params: n_estimators=200, max_depth=4, eta=0.3, radius=1, n_points=8, accuracy=0.9755, time_elapsed=6.89 seconds
# Evaluated params: n_estimators=200, max_depth=4, eta=0.3, radius=1, n_points=16, accuracy=0.9779, time_elapsed=7.24 seconds
# Evaluated params: n_estimators=200, max_depth=4, eta=0.3, radius=1, n_points=24, accuracy=0.9776, time_elapsed=7.05 seconds
# Evaluated params: n_estimators=200, max_depth=4, eta=0.3, radius=2, n_points=8, accuracy=0.9816, time_elapsed=7.85 seconds
# Evaluated params: n_estimators=200, max_depth=4, eta=0.3, radius=2, n_points=16, accuracy=0.9818, time_elapsed=8.30 seconds
# Evaluated params: n_estimators=200, max_depth=4, eta=0.3, radius=2, n_points=24, accuracy=0.9833, time_elapsed=8.47 seconds
# Evaluated params: n_estimators=200, max_depth=4, eta=0.3, radius=3, n_points=8, accuracy=0.9871, time_elapsed=9.37 seconds
# Evaluated params: n_estimators=200, max_depth=4, eta=0.3, radius=3, n_points=16, accuracy=0.9877, time_elapsed=9.83 seconds
# Evaluated params: n_estimators=200, max_depth=4, eta=0.3, radius=3, n_points=24, accuracy=0.9875, time_elapsed=10.35 seconds
# Evaluated params: n_estimators=200, max_depth=6, eta=0.05, radius=1, n_points=8, accuracy=0.9743, time_elapsed=7.32 seconds
# Evaluated params: n_estimators=200, max_depth=6, eta=0.05, radius=1, n_points=16, accuracy=0.9759, time_elapsed=7.38 seconds
# Evaluated params: n_estimators=200, max_depth=6, eta=0.05, radius=1, n_points=24, accuracy=0.9758, time_elapsed=7.74 seconds
# Evaluated params: n_estimators=200, max_depth=6, eta=0.05, radius=2, n_points=8, accuracy=0.9781, time_elapsed=8.65 seconds
# Evaluated params: n_estimators=200, max_depth=6, eta=0.05, radius=2, n_points=16, accuracy=0.9795, time_elapsed=9.02 seconds
# Evaluated params: n_estimators=200, max_depth=6, eta=0.05, radius=2, n_points=24, accuracy=0.9795, time_elapsed=8.96 seconds
# Evaluated params: n_estimators=200, max_depth=6, eta=0.05, radius=3, n_points=8, accuracy=0.9836, time_elapsed=10.20 seconds
# Evaluated params: n_estimators=200, max_depth=6, eta=0.05, radius=3, n_points=16, accuracy=0.9833, time_elapsed=10.77 seconds
# Evaluated params: n_estimators=200, max_depth=6, eta=0.05, radius=3, n_points=24, accuracy=0.9838, time_elapsed=11.34 seconds
# Evaluated params: n_estimators=200, max_depth=6, eta=0.1, radius=1, n_points=8, accuracy=0.9753, time_elapsed=7.70 seconds
# Evaluated params: n_estimators=200, max_depth=6, eta=0.1, radius=1, n_points=16, accuracy=0.9770, time_elapsed=7.51 seconds
# Evaluated params: n_estimators=200, max_depth=6, eta=0.1, radius=1, n_points=24, accuracy=0.9772, time_elapsed=7.52 seconds
# Evaluated params: n_estimators=200, max_depth=6, eta=0.1, radius=2, n_points=8, accuracy=0.9810, time_elapsed=8.49 seconds
# Evaluated params: n_estimators=200, max_depth=6, eta=0.1, radius=2, n_points=16, accuracy=0.9811, time_elapsed=8.68 seconds
# Evaluated params: n_estimators=200, max_depth=6, eta=0.1, radius=2, n_points=24, accuracy=0.9816, time_elapsed=9.16 seconds
# Evaluated params: n_estimators=200, max_depth=6, eta=0.1, radius=3, n_points=8, accuracy=0.9872, time_elapsed=10.13 seconds
# Evaluated params: n_estimators=200, max_depth=6, eta=0.1, radius=3, n_points=16, accuracy=0.9863, time_elapsed=10.61 seconds
# Evaluated params: n_estimators=200, max_depth=6, eta=0.1, radius=3, n_points=24, accuracy=0.9867, time_elapsed=11.08 seconds
# Evaluated params: n_estimators=200, max_depth=6, eta=0.3, radius=1, n_points=8, accuracy=0.9756, time_elapsed=7.02 seconds
# Evaluated params: n_estimators=200, max_depth=6, eta=0.3, radius=1, n_points=16, accuracy=0.9778, time_elapsed=7.45 seconds
# Evaluated params: n_estimators=200, max_depth=6, eta=0.3, radius=1, n_points=24, accuracy=0.9782, time_elapsed=7.47 seconds
# Evaluated params: n_estimators=200, max_depth=6, eta=0.3, radius=2, n_points=8, accuracy=0.9827, time_elapsed=8.42 seconds
# Evaluated params: n_estimators=200, max_depth=6, eta=0.3, radius=2, n_points=16, accuracy=0.9826, time_elapsed=8.61 seconds
# Evaluated params: n_estimators=200, max_depth=6, eta=0.3, radius=2, n_points=24, accuracy=0.9833, time_elapsed=9.18 seconds
# Evaluated params: n_estimators=200, max_depth=6, eta=0.3, radius=3, n_points=8, accuracy=0.9886, time_elapsed=10.15 seconds
# Evaluated params: n_estimators=200, max_depth=6, eta=0.3, radius=3, n_points=16, accuracy=0.9880, time_elapsed=11.03 seconds
# Evaluated params: n_estimators=200, max_depth=6, eta=0.3, radius=3, n_points=24, accuracy=0.9887, time_elapsed=11.29 seconds
# Evaluated params: n_estimators=200, max_depth=8, eta=0.05, radius=1, n_points=8, accuracy=0.9747, time_elapsed=8.63 seconds
# Evaluated params: n_estimators=200, max_depth=8, eta=0.05, radius=1, n_points=16, accuracy=0.9767, time_elapsed=8.84 seconds
# Evaluated params: n_estimators=200, max_depth=8, eta=0.05, radius=1, n_points=24, accuracy=0.9771, time_elapsed=8.09 seconds
# Evaluated params: n_estimators=200, max_depth=8, eta=0.05, radius=2, n_points=8, accuracy=0.9796, time_elapsed=9.17 seconds
# Evaluated params: n_estimators=200, max_depth=8, eta=0.05, radius=2, n_points=16, accuracy=0.9808, time_elapsed=9.18 seconds
# Evaluated params: n_estimators=200, max_depth=8, eta=0.05, radius=2, n_points=24, accuracy=0.9807, time_elapsed=9.60 seconds
# Evaluated params: n_estimators=200, max_depth=8, eta=0.05, radius=3, n_points=8, accuracy=0.9861, time_elapsed=10.59 seconds
# Evaluated params: n_estimators=200, max_depth=8, eta=0.05, radius=3, n_points=16, accuracy=0.9855, time_elapsed=11.29 seconds
# Evaluated params: n_estimators=200, max_depth=8, eta=0.05, radius=3, n_points=24, accuracy=0.9848, time_elapsed=11.94 seconds
# Evaluated params: n_estimators=200, max_depth=8, eta=0.1, radius=1, n_points=8, accuracy=0.9758, time_elapsed=7.64 seconds
# Evaluated params: n_estimators=200, max_depth=8, eta=0.1, radius=1, n_points=16, accuracy=0.9772, time_elapsed=8.13 seconds
# Evaluated params: n_estimators=200, max_depth=8, eta=0.1, radius=1, n_points=24, accuracy=0.9782, time_elapsed=8.29 seconds
# Evaluated params: n_estimators=200, max_depth=8, eta=0.1, radius=2, n_points=8, accuracy=0.9811, time_elapsed=9.03 seconds
# Evaluated params: n_estimators=200, max_depth=8, eta=0.1, radius=2, n_points=16, accuracy=0.9822, time_elapsed=9.55 seconds
# Evaluated params: n_estimators=200, max_depth=8, eta=0.1, radius=2, n_points=24, accuracy=0.9824, time_elapsed=9.76 seconds
# Evaluated params: n_estimators=200, max_depth=8, eta=0.1, radius=3, n_points=8, accuracy=0.9875, time_elapsed=11.07 seconds
# Evaluated params: n_estimators=200, max_depth=8, eta=0.1, radius=3, n_points=16, accuracy=0.9876, time_elapsed=11.23 seconds
# Evaluated params: n_estimators=200, max_depth=8, eta=0.1, radius=3, n_points=24, accuracy=0.9873, time_elapsed=12.28 seconds
# Evaluated params: n_estimators=200, max_depth=8, eta=0.3, radius=1, n_points=8, accuracy=0.9762, time_elapsed=7.64 seconds
# Evaluated params: n_estimators=200, max_depth=8, eta=0.3, radius=1, n_points=16, accuracy=0.9774, time_elapsed=7.75 seconds
# Evaluated params: n_estimators=200, max_depth=8, eta=0.3, radius=1, n_points=24, accuracy=0.9782, time_elapsed=8.05 seconds
# Evaluated params: n_estimators=200, max_depth=8, eta=0.3, radius=2, n_points=8, accuracy=0.9817, time_elapsed=9.15 seconds
# Evaluated params: n_estimators=200, max_depth=8, eta=0.3, radius=2, n_points=16, accuracy=0.9833, time_elapsed=9.13 seconds
# Evaluated params: n_estimators=200, max_depth=8, eta=0.3, radius=2, n_points=24, accuracy=0.9833, time_elapsed=9.61 seconds
# Evaluated params: n_estimators=200, max_depth=8, eta=0.3, radius=3, n_points=8, accuracy=0.9879, time_elapsed=10.54 seconds
# Evaluated params: n_estimators=200, max_depth=8, eta=0.3, radius=3, n_points=16, accuracy=0.9884, time_elapsed=11.09 seconds
# Evaluated params: n_estimators=200, max_depth=8, eta=0.3, radius=3, n_points=24, accuracy=0.9883, time_elapsed=11.93 seconds
# Evaluated params: n_estimators=300, max_depth=4, eta=0.05, radius=1, n_points=8, accuracy=0.9734, time_elapsed=7.47 seconds
# Evaluated params: n_estimators=300, max_depth=4, eta=0.05, radius=1, n_points=16, accuracy=0.9753, time_elapsed=7.85 seconds
# Evaluated params: n_estimators=300, max_depth=4, eta=0.05, radius=1, n_points=24, accuracy=0.9755, time_elapsed=8.19 seconds
# Evaluated params: n_estimators=300, max_depth=4, eta=0.05, radius=2, n_points=8, accuracy=0.9778, time_elapsed=9.34 seconds
# Evaluated params: n_estimators=300, max_depth=4, eta=0.05, radius=2, n_points=16, accuracy=0.9781, time_elapsed=9.47 seconds
# Evaluated params: n_estimators=300, max_depth=4, eta=0.05, radius=2, n_points=24, accuracy=0.9788, time_elapsed=9.63 seconds
# Evaluated params: n_estimators=300, max_depth=4, eta=0.05, radius=3, n_points=8, accuracy=0.9822, time_elapsed=10.72 seconds
# Evaluated params: n_estimators=300, max_depth=4, eta=0.05, radius=3, n_points=16, accuracy=0.9832, time_elapsed=11.17 seconds
# Evaluated params: n_estimators=300, max_depth=4, eta=0.05, radius=3, n_points=24, accuracy=0.9827, time_elapsed=12.16 seconds
# Evaluated params: n_estimators=300, max_depth=4, eta=0.1, radius=1, n_points=8, accuracy=0.9753, time_elapsed=7.70 seconds
# Evaluated params: n_estimators=300, max_depth=4, eta=0.1, radius=1, n_points=16, accuracy=0.9773, time_elapsed=7.52 seconds
# Evaluated params: n_estimators=300, max_depth=4, eta=0.1, radius=1, n_points=24, accuracy=0.9775, time_elapsed=8.19 seconds
# Evaluated params: n_estimators=300, max_depth=4, eta=0.1, radius=2, n_points=8, accuracy=0.9804, time_elapsed=9.29 seconds
# Evaluated params: n_estimators=300, max_depth=4, eta=0.1, radius=2, n_points=16, accuracy=0.9809, time_elapsed=9.08 seconds
# Evaluated params: n_estimators=300, max_depth=4, eta=0.1, radius=2, n_points=24, accuracy=0.9819, time_elapsed=9.99 seconds
# Evaluated params: n_estimators=300, max_depth=4, eta=0.1, radius=3, n_points=8, accuracy=0.9855, time_elapsed=11.17 seconds
# Evaluated params: n_estimators=300, max_depth=4, eta=0.1, radius=3, n_points=16, accuracy=0.9864, time_elapsed=11.61 seconds
# Evaluated params: n_estimators=300, max_depth=4, eta=0.1, radius=3, n_points=24, accuracy=0.9861, time_elapsed=12.49 seconds
# Evaluated params: n_estimators=300, max_depth=4, eta=0.3, radius=1, n_points=8, accuracy=0.9760, time_elapsed=7.79 seconds
# Evaluated params: n_estimators=300, max_depth=4, eta=0.3, radius=1, n_points=16, accuracy=0.9781, time_elapsed=7.80 seconds
# Evaluated params: n_estimators=300, max_depth=4, eta=0.3, radius=1, n_points=24, accuracy=0.9778, time_elapsed=7.80 seconds
# Evaluated params: n_estimators=300, max_depth=4, eta=0.3, radius=2, n_points=8, accuracy=0.9819, time_elapsed=8.89 seconds
# Evaluated params: n_estimators=300, max_depth=4, eta=0.3, radius=2, n_points=16, accuracy=0.9825, time_elapsed=9.06 seconds
# Evaluated params: n_estimators=300, max_depth=4, eta=0.3, radius=2, n_points=24, accuracy=0.9834, time_elapsed=9.49 seconds
# Evaluated params: n_estimators=300, max_depth=4, eta=0.3, radius=3, n_points=8, accuracy=0.9876, time_elapsed=10.42 seconds
# Evaluated params: n_estimators=300, max_depth=4, eta=0.3, radius=3, n_points=16, accuracy=0.9883, time_elapsed=11.07 seconds
# Evaluated params: n_estimators=300, max_depth=4, eta=0.3, radius=3, n_points=24, accuracy=0.9885, time_elapsed=11.86 seconds
# Evaluated params: n_estimators=300, max_depth=6, eta=0.05, radius=1, n_points=8, accuracy=0.9753, time_elapsed=8.71 seconds
# Evaluated params: n_estimators=300, max_depth=6, eta=0.05, radius=1, n_points=16, accuracy=0.9768, time_elapsed=8.23 seconds
# Evaluated params: n_estimators=300, max_depth=6, eta=0.05, radius=1, n_points=24, accuracy=0.9772, time_elapsed=8.76 seconds
# Evaluated params: n_estimators=300, max_depth=6, eta=0.05, radius=2, n_points=8, accuracy=0.9802, time_elapsed=9.66 seconds
# Evaluated params: n_estimators=300, max_depth=6, eta=0.05, radius=2, n_points=16, accuracy=0.9808, time_elapsed=10.28 seconds
# Evaluated params: n_estimators=300, max_depth=6, eta=0.05, radius=2, n_points=24, accuracy=0.9812, time_elapsed=10.44 seconds
# Evaluated params: n_estimators=300, max_depth=6, eta=0.05, radius=3, n_points=8, accuracy=0.9859, time_elapsed=11.58 seconds
# Evaluated params: n_estimators=300, max_depth=6, eta=0.05, radius=3, n_points=16, accuracy=0.9855, time_elapsed=12.32 seconds
# Evaluated params: n_estimators=300, max_depth=6, eta=0.05, radius=3, n_points=24, accuracy=0.9859, time_elapsed=12.93 seconds
# Evaluated params: n_estimators=300, max_depth=6, eta=0.1, radius=1, n_points=8, accuracy=0.9753, time_elapsed=8.66 seconds
# Evaluated params: n_estimators=300, max_depth=6, eta=0.1, radius=1, n_points=16, accuracy=0.9778, time_elapsed=8.77 seconds
# Evaluated params: n_estimators=300, max_depth=6, eta=0.1, radius=1, n_points=24, accuracy=0.9778, time_elapsed=9.11 seconds
# Evaluated params: n_estimators=300, max_depth=6, eta=0.1, radius=2, n_points=8, accuracy=0.9815, time_elapsed=10.51 seconds
# Evaluated params: n_estimators=300, max_depth=6, eta=0.1, radius=2, n_points=16, accuracy=0.9822, time_elapsed=10.56 seconds
# Evaluated params: n_estimators=300, max_depth=6, eta=0.1, radius=2, n_points=24, accuracy=0.9825, time_elapsed=10.90 seconds
# Evaluated params: n_estimators=300, max_depth=6, eta=0.1, radius=3, n_points=8, accuracy=0.9882, time_elapsed=12.43 seconds
# Evaluated params: n_estimators=300, max_depth=6, eta=0.1, radius=3, n_points=16, accuracy=0.9874, time_elapsed=13.70 seconds
# Evaluated params: n_estimators=300, max_depth=6, eta=0.1, radius=3, n_points=24, accuracy=0.9872, time_elapsed=13.02 seconds
# Evaluated params: n_estimators=300, max_depth=6, eta=0.3, radius=1, n_points=8, accuracy=0.9761, time_elapsed=8.42 seconds
# Evaluated params: n_estimators=300, max_depth=6, eta=0.3, radius=1, n_points=16, accuracy=0.9779, time_elapsed=8.44 seconds
# Evaluated params: n_estimators=300, max_depth=6, eta=0.3, radius=1, n_points=24, accuracy=0.9783, time_elapsed=8.63 seconds
# Evaluated params: n_estimators=300, max_depth=6, eta=0.3, radius=2, n_points=8, accuracy=0.9832, time_elapsed=9.68 seconds
# Evaluated params: n_estimators=300, max_depth=6, eta=0.3, radius=2, n_points=16, accuracy=0.9832, time_elapsed=9.87 seconds
# Evaluated params: n_estimators=300, max_depth=6, eta=0.3, radius=2, n_points=24, accuracy=0.9835, time_elapsed=10.25 seconds
# Evaluated params: n_estimators=300, max_depth=6, eta=0.3, radius=3, n_points=8, accuracy=0.9886, time_elapsed=12.21 seconds
# Evaluated params: n_estimators=300, max_depth=6, eta=0.3, radius=3, n_points=16, accuracy=0.9885, time_elapsed=12.43 seconds
# Evaluated params: n_estimators=300, max_depth=6, eta=0.3, radius=3, n_points=24, accuracy=0.9888, time_elapsed=13.13 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.05, radius=1, n_points=8, accuracy=0.9751, time_elapsed=9.15 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.05, radius=1, n_points=16, accuracy=0.9771, time_elapsed=9.43 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.05, radius=1, n_points=24, accuracy=0.9777, time_elapsed=9.53 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.05, radius=2, n_points=8, accuracy=0.9810, time_elapsed=10.91 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.05, radius=2, n_points=16, accuracy=0.9817, time_elapsed=11.58 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.05, radius=2, n_points=24, accuracy=0.9817, time_elapsed=11.39 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.05, radius=3, n_points=8, accuracy=0.9870, time_elapsed=12.87 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.05, radius=3, n_points=16, accuracy=0.9870, time_elapsed=13.38 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.05, radius=3, n_points=24, accuracy=0.9865, time_elapsed=14.35 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.1, radius=1, n_points=8, accuracy=0.9757, time_elapsed=8.83 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.1, radius=1, n_points=16, accuracy=0.9775, time_elapsed=9.21 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.1, radius=1, n_points=24, accuracy=0.9783, time_elapsed=9.07 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.1, radius=2, n_points=8, accuracy=0.9817, time_elapsed=10.40 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.1, radius=2, n_points=16, accuracy=0.9826, time_elapsed=11.18 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.1, radius=2, n_points=24, accuracy=0.9826, time_elapsed=11.45 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.1, radius=3, n_points=8, accuracy=0.9880, time_elapsed=13.45 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.1, radius=3, n_points=16, accuracy=0.9881, time_elapsed=13.75 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.1, radius=3, n_points=24, accuracy=0.9877, time_elapsed=14.96 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.3, radius=1, n_points=8, accuracy=0.9765, time_elapsed=9.13 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.3, radius=1, n_points=16, accuracy=0.9777, time_elapsed=9.17 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.3, radius=1, n_points=24, accuracy=0.9782, time_elapsed=9.01 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.3, radius=2, n_points=8, accuracy=0.9820, time_elapsed=10.55 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.3, radius=2, n_points=16, accuracy=0.9838, time_elapsed=10.62 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.3, radius=2, n_points=24, accuracy=0.9831, time_elapsed=10.67 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.3, radius=3, n_points=8, accuracy=0.9881, time_elapsed=11.98 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.3, radius=3, n_points=16, accuracy=0.9886, time_elapsed=12.46 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.3, radius=3, n_points=24, accuracy=0.9885, time_elapsed=13.22 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.05, radius=1, n_points=8, accuracy=0.9747, time_elapsed=8.65 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.05, radius=1, n_points=16, accuracy=0.9772, time_elapsed=8.98 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.05, radius=1, n_points=24, accuracy=0.9765, time_elapsed=9.04 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.05, radius=2, n_points=8, accuracy=0.9802, time_elapsed=10.76 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.05, radius=2, n_points=16, accuracy=0.9805, time_elapsed=11.06 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.05, radius=2, n_points=24, accuracy=0.9808, time_elapsed=11.19 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.05, radius=3, n_points=8, accuracy=0.9845, time_elapsed=13.35 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.05, radius=3, n_points=16, accuracy=0.9855, time_elapsed=13.90 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.05, radius=3, n_points=24, accuracy=0.9853, time_elapsed=14.55 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.1, radius=1, n_points=8, accuracy=0.9760, time_elapsed=9.06 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.1, radius=1, n_points=16, accuracy=0.9780, time_elapsed=9.00 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.1, radius=1, n_points=24, accuracy=0.9780, time_elapsed=9.16 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.1, radius=2, n_points=8, accuracy=0.9814, time_elapsed=10.80 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.1, radius=2, n_points=16, accuracy=0.9824, time_elapsed=11.06 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.1, radius=2, n_points=24, accuracy=0.9833, time_elapsed=11.31 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.1, radius=3, n_points=8, accuracy=0.9869, time_elapsed=13.10 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.1, radius=3, n_points=16, accuracy=0.9874, time_elapsed=14.20 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.1, radius=3, n_points=24, accuracy=0.9879, time_elapsed=15.28 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.3, radius=1, n_points=8, accuracy=0.9759, time_elapsed=9.99 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.3, radius=1, n_points=16, accuracy=0.9783, time_elapsed=8.89 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.3, radius=1, n_points=24, accuracy=0.9781, time_elapsed=9.35 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.3, radius=2, n_points=8, accuracy=0.9820, time_elapsed=10.66 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.3, radius=2, n_points=16, accuracy=0.9827, time_elapsed=11.28 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.3, radius=2, n_points=24, accuracy=0.9836, time_elapsed=11.53 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.3, radius=3, n_points=8, accuracy=0.9882, time_elapsed=12.87 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.3, radius=3, n_points=16, accuracy=0.9891, time_elapsed=13.74 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.3, radius=3, n_points=24, accuracy=0.9888, time_elapsed=15.86 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.05, radius=1, n_points=8, accuracy=0.9752, time_elapsed=11.27 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.05, radius=1, n_points=16, accuracy=0.9770, time_elapsed=10.41 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.05, radius=1, n_points=24, accuracy=0.9777, time_elapsed=10.36 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.05, radius=2, n_points=8, accuracy=0.9811, time_elapsed=12.35 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.05, radius=2, n_points=16, accuracy=0.9817, time_elapsed=12.70 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.05, radius=2, n_points=24, accuracy=0.9824, time_elapsed=13.02 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.05, radius=3, n_points=8, accuracy=0.9874, time_elapsed=14.98 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.05, radius=3, n_points=16, accuracy=0.9867, time_elapsed=16.19 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.05, radius=3, n_points=24, accuracy=0.9872, time_elapsed=16.36 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.1, radius=1, n_points=8, accuracy=0.9755, time_elapsed=10.33 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.1, radius=1, n_points=16, accuracy=0.9784, time_elapsed=10.84 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.1, radius=1, n_points=24, accuracy=0.9780, time_elapsed=10.73 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.1, radius=2, n_points=8, accuracy=0.9826, time_elapsed=12.91 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.1, radius=2, n_points=16, accuracy=0.9828, time_elapsed=12.65 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.1, radius=2, n_points=24, accuracy=0.9828, time_elapsed=13.38 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.1, radius=3, n_points=8, accuracy=0.9883, time_elapsed=16.03 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.1, radius=3, n_points=16, accuracy=0.9880, time_elapsed=16.34 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.1, radius=3, n_points=24, accuracy=0.9884, time_elapsed=19.07 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.3, radius=1, n_points=8, accuracy=0.9762, time_elapsed=10.64 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.3, radius=1, n_points=16, accuracy=0.9781, time_elapsed=11.14 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.3, radius=1, n_points=24, accuracy=0.9787, time_elapsed=10.96 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.3, radius=2, n_points=8, accuracy=0.9833, time_elapsed=13.38 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.3, radius=2, n_points=16, accuracy=0.9831, time_elapsed=13.10 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.3, radius=2, n_points=24, accuracy=0.9836, time_elapsed=14.56 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.3, radius=3, n_points=8, accuracy=0.9890, time_elapsed=17.27 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.3, radius=3, n_points=16, accuracy=0.9889, time_elapsed=18.29 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.3, radius=3, n_points=24, accuracy=0.9889, time_elapsed=20.87 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.05, radius=1, n_points=8, accuracy=0.9755, time_elapsed=13.94 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.05, radius=1, n_points=16, accuracy=0.9774, time_elapsed=12.40 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.05, radius=1, n_points=24, accuracy=0.9780, time_elapsed=12.76 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.05, radius=2, n_points=8, accuracy=0.9822, time_elapsed=15.43 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.05, radius=2, n_points=16, accuracy=0.9826, time_elapsed=16.31 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.05, radius=2, n_points=24, accuracy=0.9828, time_elapsed=18.32 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.05, radius=3, n_points=8, accuracy=0.9880, time_elapsed=22.32 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.05, radius=3, n_points=16, accuracy=0.9877, time_elapsed=23.04 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.05, radius=3, n_points=24, accuracy=0.9876, time_elapsed=22.99 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.1, radius=1, n_points=8, accuracy=0.9763, time_elapsed=13.96 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.1, radius=1, n_points=16, accuracy=0.9774, time_elapsed=14.49 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.1, radius=1, n_points=24, accuracy=0.9783, time_elapsed=13.69 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.1, radius=2, n_points=8, accuracy=0.9819, time_elapsed=16.87 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.1, radius=2, n_points=16, accuracy=0.9835, time_elapsed=17.93 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.1, radius=2, n_points=24, accuracy=0.9832, time_elapsed=18.63 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.1, radius=3, n_points=8, accuracy=0.9886, time_elapsed=21.98 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.1, radius=3, n_points=16, accuracy=0.9887, time_elapsed=24.34 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.1, radius=3, n_points=24, accuracy=0.9881, time_elapsed=27.27 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.3, radius=1, n_points=8, accuracy=0.9765, time_elapsed=16.67 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.3, radius=1, n_points=16, accuracy=0.9779, time_elapsed=17.44 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.3, radius=1, n_points=24, accuracy=0.9782, time_elapsed=17.37 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.3, radius=2, n_points=8, accuracy=0.9821, time_elapsed=24.86 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.3, radius=2, n_points=16, accuracy=0.9838, time_elapsed=25.18 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.3, radius=2, n_points=24, accuracy=0.9834, time_elapsed=24.37 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.3, radius=3, n_points=8, accuracy=0.9884, time_elapsed=27.31 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.3, radius=3, n_points=16, accuracy=0.9887, time_elapsed=25.23 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.3, radius=3, n_points=24, accuracy=0.9885, time_elapsed=24.85 seconds
#
# Best Parameters: {'n_estimators': 500, 'max_depth': 4, 'eta': 0.3, 'radius': 3, 'n_points': 16, 'accuracy': 0.9890676487691413, 'time_elapsed': 13.74214379201294}
#
# Top 5 Parameters:
# Rank  n_estimators max_depth  eta    radius   n_points   accuracy time(s)
# 1     500          4          0.30   3        16         0.9891   13.74
# 2     500          6          0.30   3        8          0.9890   17.27
# 3     500          6          0.30   3        16         0.9889   18.29
# 4     500          6          0.30   3        24         0.9889   20.87
# 5     300          6          0.30   3        24         0.9888   13.13
# 6     500          4          0.30   3        24         0.9888   15.86
# 7     200          6          0.30   3        24         0.9887   11.29
# 8     500          8          0.30   3        16         0.9887   25.23
# 9     500          8          0.10   3        16         0.9887   24.34
# 10    200          6          0.30   3        8          0.9886   10.15
#
# Top 10 Parameters that take to account time:
# Rank  n_estimators max_depth  eta    accuracy time(s)
# 1     100          4          0.05   0.9677   6.11
# 2     100          4          0.30   0.9753   6.15
# 3     100          4          0.05   0.9695   6.21
# 4     100          4          0.30   0.9765   6.23
# 5     100          6          0.30   0.9753   6.24
# 6     100          6          0.10   0.9743   6.27
# 7     100          4          0.10   0.9719   6.28
# 8     100          4          0.05   0.9706   6.34
# 9     100          4          0.10   0.9738   6.38
# 10    100          4          0.30   0.9766   6.38
# Accuracy: 98.91%
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     15627
#            1       0.98      0.99      0.99      6024
#            2       0.95      0.95      0.95      1852
#            3       0.96      0.95      0.96      2292
#
#     accuracy                           0.99     25795
#    macro avg       0.97      0.97      0.97     25795
# weighted avg       0.99      0.99      0.99     25795
#
# Value for radius is $3
# Value for radius is $16
# Unique colors in eval_mask (BGR): {(0, 0, 0): 7898, (0, 255, 0): 38258, (0, 255, 255): 12154, (255, 0, 0): 96852, (255, 255, 255): 106982}
# Evaluation Accuracy on Eval Image: 97.69%
# Evaluation Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99     96852
#            1       0.96      0.97      0.97     38258
#            2       0.88      0.94      0.91      7898
#            3       0.97      0.86      0.92     12154
#
#     accuracy                           0.98    155162
#    macro avg       0.95      0.94      0.95    155162
# weighted avg       0.98      0.98      0.98    155162
#
# Time taken for first image pair processing: 3596.12 seconds
# ==================================
# Evaluation SS2
# ==================================
# Evaluated params: n_estimators=100, max_depth=4, eta=0.05, radius=1, n_points=8, accuracy=0.9217, time_elapsed=2.95 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.05, radius=1, n_points=16, accuracy=0.9220, time_elapsed=3.30 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.05, radius=1, n_points=24, accuracy=0.9233, time_elapsed=3.71 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.05, radius=2, n_points=8, accuracy=0.9323, time_elapsed=4.60 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.05, radius=2, n_points=16, accuracy=0.9286, time_elapsed=4.99 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.05, radius=2, n_points=24, accuracy=0.9281, time_elapsed=5.62 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.05, radius=3, n_points=8, accuracy=0.9316, time_elapsed=5.74 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.05, radius=3, n_points=16, accuracy=0.9280, time_elapsed=5.78 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.05, radius=3, n_points=24, accuracy=0.9275, time_elapsed=6.13 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.1, radius=1, n_points=8, accuracy=0.9322, time_elapsed=4.16 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.1, radius=1, n_points=16, accuracy=0.9360, time_elapsed=4.00 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.1, radius=1, n_points=24, accuracy=0.9361, time_elapsed=3.95 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.1, radius=2, n_points=8, accuracy=0.9432, time_elapsed=4.33 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.1, radius=2, n_points=16, accuracy=0.9441, time_elapsed=4.58 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.1, radius=2, n_points=24, accuracy=0.9430, time_elapsed=4.81 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.1, radius=3, n_points=8, accuracy=0.9460, time_elapsed=5.22 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.1, radius=3, n_points=16, accuracy=0.9414, time_elapsed=7.16 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.1, radius=3, n_points=24, accuracy=0.9437, time_elapsed=6.15 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.3, radius=1, n_points=8, accuracy=0.9409, time_elapsed=3.16 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.3, radius=1, n_points=16, accuracy=0.9434, time_elapsed=3.68 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.3, radius=1, n_points=24, accuracy=0.9449, time_elapsed=4.55 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.3, radius=2, n_points=8, accuracy=0.9532, time_elapsed=4.89 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.3, radius=2, n_points=16, accuracy=0.9528, time_elapsed=5.99 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.3, radius=2, n_points=24, accuracy=0.9540, time_elapsed=5.79 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.3, radius=3, n_points=8, accuracy=0.9558, time_elapsed=6.51 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.3, radius=3, n_points=16, accuracy=0.9546, time_elapsed=7.01 seconds
# Evaluated params: n_estimators=100, max_depth=4, eta=0.3, radius=3, n_points=24, accuracy=0.9585, time_elapsed=8.10 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.05, radius=1, n_points=8, accuracy=0.9322, time_elapsed=6.26 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.05, radius=1, n_points=16, accuracy=0.9361, time_elapsed=6.12 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.05, radius=1, n_points=24, accuracy=0.9356, time_elapsed=5.97 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.05, radius=2, n_points=8, accuracy=0.9439, time_elapsed=6.18 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.05, radius=2, n_points=16, accuracy=0.9407, time_elapsed=6.58 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.05, radius=2, n_points=24, accuracy=0.9399, time_elapsed=6.92 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.05, radius=3, n_points=8, accuracy=0.9446, time_elapsed=7.81 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.05, radius=3, n_points=16, accuracy=0.9399, time_elapsed=8.44 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.05, radius=3, n_points=24, accuracy=0.9419, time_elapsed=8.85 seconds
# Evaluated params: n_estimators=100, max_depth=6, eta=0.1, radius=1, n_points=8, accuracy=0.9385, time_elapsed=5.89 seconds
# ...
# Evaluated params: n_estimators=300, max_depth=8, eta=0.05, radius=2, n_points=8, accuracy=0.9534, time_elapsed=14.34 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.05, radius=2, n_points=16, accuracy=0.9507, time_elapsed=15.12 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.05, radius=2, n_points=24, accuracy=0.9510, time_elapsed=14.16 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.05, radius=3, n_points=8, accuracy=0.9550, time_elapsed=18.09 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.05, radius=3, n_points=16, accuracy=0.9525, time_elapsed=18.55 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.05, radius=3, n_points=24, accuracy=0.9541, time_elapsed=22.88 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.1, radius=1, n_points=8, accuracy=0.9411, time_elapsed=11.28 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.1, radius=1, n_points=16, accuracy=0.9443, time_elapsed=11.86 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.1, radius=1, n_points=24, accuracy=0.9433, time_elapsed=12.30 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.1, radius=2, n_points=8, accuracy=0.9559, time_elapsed=14.08 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.1, radius=2, n_points=16, accuracy=0.9529, time_elapsed=16.10 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.1, radius=2, n_points=24, accuracy=0.9539, time_elapsed=13.31 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.1, radius=3, n_points=8, accuracy=0.9577, time_elapsed=16.24 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.1, radius=3, n_points=16, accuracy=0.9544, time_elapsed=16.57 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.1, radius=3, n_points=24, accuracy=0.9565, time_elapsed=16.88 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.3, radius=1, n_points=8, accuracy=0.9419, time_elapsed=9.81 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.3, radius=1, n_points=16, accuracy=0.9453, time_elapsed=9.43 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.3, radius=1, n_points=24, accuracy=0.9440, time_elapsed=9.99 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.3, radius=2, n_points=8, accuracy=0.9573, time_elapsed=11.01 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.3, radius=2, n_points=16, accuracy=0.9545, time_elapsed=11.81 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.3, radius=2, n_points=24, accuracy=0.9545, time_elapsed=11.14 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.3, radius=3, n_points=8, accuracy=0.9595, time_elapsed=13.85 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.3, radius=3, n_points=16, accuracy=0.9580, time_elapsed=14.38 seconds
# Evaluated params: n_estimators=300, max_depth=8, eta=0.3, radius=3, n_points=24, accuracy=0.9592, time_elapsed=17.79 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.05, radius=1, n_points=8, accuracy=0.9407, time_elapsed=10.35 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.05, radius=1, n_points=16, accuracy=0.9424, time_elapsed=10.86 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.05, radius=1, n_points=24, accuracy=0.9427, time_elapsed=8.17 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.05, radius=2, n_points=8, accuracy=0.9514, time_elapsed=13.61 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.05, radius=2, n_points=16, accuracy=0.9515, time_elapsed=13.26 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.05, radius=2, n_points=24, accuracy=0.9522, time_elapsed=13.14 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.05, radius=3, n_points=8, accuracy=0.9561, time_elapsed=17.02 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.05, radius=3, n_points=16, accuracy=0.9544, time_elapsed=17.35 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.05, radius=3, n_points=24, accuracy=0.9557, time_elapsed=19.28 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.1, radius=1, n_points=8, accuracy=0.9429, time_elapsed=11.56 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.1, radius=1, n_points=16, accuracy=0.9447, time_elapsed=12.12 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.1, radius=1, n_points=24, accuracy=0.9458, time_elapsed=13.09 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.1, radius=2, n_points=8, accuracy=0.9544, time_elapsed=14.68 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.1, radius=2, n_points=16, accuracy=0.9551, time_elapsed=14.83 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.1, radius=2, n_points=24, accuracy=0.9543, time_elapsed=15.34 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.1, radius=3, n_points=8, accuracy=0.9611, time_elapsed=17.93 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.1, radius=3, n_points=16, accuracy=0.9590, time_elapsed=17.73 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.1, radius=3, n_points=24, accuracy=0.9608, time_elapsed=19.63 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.3, radius=1, n_points=8, accuracy=0.9394, time_elapsed=11.02 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.3, radius=1, n_points=16, accuracy=0.9440, time_elapsed=11.95 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.3, radius=1, n_points=24, accuracy=0.9453, time_elapsed=12.99 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.3, radius=2, n_points=8, accuracy=0.9581, time_elapsed=14.60 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.3, radius=2, n_points=16, accuracy=0.9570, time_elapsed=15.14 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.3, radius=2, n_points=24, accuracy=0.9589, time_elapsed=15.44 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.3, radius=3, n_points=8, accuracy=0.9630, time_elapsed=20.11 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.3, radius=3, n_points=16, accuracy=0.9641, time_elapsed=18.63 seconds
# Evaluated params: n_estimators=500, max_depth=4, eta=0.3, radius=3, n_points=24, accuracy=0.9652, time_elapsed=20.30 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.05, radius=1, n_points=8, accuracy=0.9419, time_elapsed=15.12 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.05, radius=1, n_points=16, accuracy=0.9451, time_elapsed=13.98 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.05, radius=1, n_points=24, accuracy=0.9452, time_elapsed=11.66 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.05, radius=2, n_points=8, accuracy=0.9557, time_elapsed=15.95 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.05, radius=2, n_points=16, accuracy=0.9555, time_elapsed=22.57 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.05, radius=2, n_points=24, accuracy=0.9527, time_elapsed=17.71 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.05, radius=3, n_points=8, accuracy=0.9590, time_elapsed=24.36 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.05, radius=3, n_points=16, accuracy=0.9581, time_elapsed=27.69 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.05, radius=3, n_points=24, accuracy=0.9596, time_elapsed=26.41 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.1, radius=1, n_points=8, accuracy=0.9419, time_elapsed=13.58 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.1, radius=1, n_points=16, accuracy=0.9455, time_elapsed=12.62 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.1, radius=1, n_points=24, accuracy=0.9453, time_elapsed=14.60 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.1, radius=2, n_points=8, accuracy=0.9576, time_elapsed=17.97 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.1, radius=2, n_points=16, accuracy=0.9562, time_elapsed=19.69 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.1, radius=2, n_points=24, accuracy=0.9546, time_elapsed=19.22 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.1, radius=3, n_points=8, accuracy=0.9614, time_elapsed=24.33 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.1, radius=3, n_points=16, accuracy=0.9595, time_elapsed=28.99 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.1, radius=3, n_points=24, accuracy=0.9620, time_elapsed=27.41 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.3, radius=1, n_points=8, accuracy=0.9424, time_elapsed=11.95 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.3, radius=1, n_points=16, accuracy=0.9457, time_elapsed=14.39 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.3, radius=1, n_points=24, accuracy=0.9456, time_elapsed=15.16 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.3, radius=2, n_points=8, accuracy=0.9589, time_elapsed=18.11 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.3, radius=2, n_points=16, accuracy=0.9572, time_elapsed=20.88 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.3, radius=2, n_points=24, accuracy=0.9565, time_elapsed=19.27 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.3, radius=3, n_points=8, accuracy=0.9624, time_elapsed=22.76 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.3, radius=3, n_points=16, accuracy=0.9629, time_elapsed=26.51 seconds
# Evaluated params: n_estimators=500, max_depth=6, eta=0.3, radius=3, n_points=24, accuracy=0.9630, time_elapsed=25.20 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.05, radius=1, n_points=8, accuracy=0.9412, time_elapsed=18.79 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.05, radius=1, n_points=16, accuracy=0.9445, time_elapsed=21.15 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.05, radius=1, n_points=24, accuracy=0.9427, time_elapsed=20.81 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.05, radius=2, n_points=8, accuracy=0.9545, time_elapsed=23.15 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.05, radius=2, n_points=16, accuracy=0.9527, time_elapsed=25.08 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.05, radius=2, n_points=24, accuracy=0.9535, time_elapsed=21.57 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.05, radius=3, n_points=8, accuracy=0.9569, time_elapsed=24.36 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.05, radius=3, n_points=16, accuracy=0.9542, time_elapsed=26.00 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.05, radius=3, n_points=24, accuracy=0.9565, time_elapsed=21.66 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.1, radius=1, n_points=8, accuracy=0.9415, time_elapsed=12.93 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.1, radius=1, n_points=16, accuracy=0.9453, time_elapsed=14.85 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.1, radius=1, n_points=24, accuracy=0.9433, time_elapsed=14.50 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.1, radius=2, n_points=8, accuracy=0.9565, time_elapsed=16.88 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.1, radius=2, n_points=16, accuracy=0.9550, time_elapsed=17.71 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.1, radius=2, n_points=24, accuracy=0.9549, time_elapsed=17.58 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.1, radius=3, n_points=8, accuracy=0.9589, time_elapsed=21.85 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.1, radius=3, n_points=16, accuracy=0.9573, time_elapsed=23.89 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.1, radius=3, n_points=24, accuracy=0.9585, time_elapsed=24.39 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.3, radius=1, n_points=8, accuracy=0.9421, time_elapsed=13.36 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.3, radius=1, n_points=16, accuracy=0.9451, time_elapsed=13.63 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.3, radius=1, n_points=24, accuracy=0.9445, time_elapsed=13.15 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.3, radius=2, n_points=8, accuracy=0.9578, time_elapsed=17.07 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.3, radius=2, n_points=16, accuracy=0.9546, time_elapsed=17.99 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.3, radius=2, n_points=24, accuracy=0.9553, time_elapsed=16.07 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.3, radius=3, n_points=8, accuracy=0.9607, time_elapsed=18.88 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.3, radius=3, n_points=16, accuracy=0.9592, time_elapsed=19.33 seconds
# Evaluated params: n_estimators=500, max_depth=8, eta=0.3, radius=3, n_points=24, accuracy=0.9601, time_elapsed=19.78 seconds
#
# Best Parameters: {'n_estimators': 500, 'max_depth': 4, 'eta': 0.3, 'radius': 3, 'n_points': 24, 'accuracy': 0.965166908563135, 'time_elapsed': 20.30252120801015}
#
# Top 5 Parameters:
# Rank  n_estimators max_depth  eta    radius   n_points   accuracy time(s)
# 1     500          4          0.30   3        24         0.9652   20.30
# 2     300          4          0.30   3        24         0.9645   11.89
# 3     500          4          0.30   3        16         0.9641   18.63
# 4     200          4          0.30   3        24         0.9637   10.94
# 5     500          4          0.30   3        8          0.9630   20.11
# 6     500          6          0.30   3        24         0.9630   25.20
# 7     500          6          0.30   3        16         0.9629   26.51
# 8     300          6          0.30   3        16         0.9624   15.24
# 9     500          6          0.30   3        8          0.9624   22.76
# 10    300          4          0.30   3        16         0.9623   11.31
#
# Top 10 Parameters that take to account time:
# Rank  n_estimators max_depth  eta    accuracy time(s)
# 1     100          4          0.05   0.9217   2.95
# 2     100          4          0.30   0.9409   3.16
# 3     100          4          0.05   0.9220   3.30
# 4     100          4          0.30   0.9434   3.68
# 5     100          4          0.05   0.9233   3.71
# 6     100          4          0.10   0.9361   3.95
# 7     100          4          0.10   0.9360   4.00
# 8     100          4          0.10   0.9322   4.16
# 9     100          4          0.10   0.9432   4.33
# 10    100          4          0.30   0.9449   4.55
# Accuracy: 96.52%
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98      1234
#            1       0.94      0.93      0.94      1821
#            2       0.97      0.98      0.97      4592
#            3       0.97      0.96      0.97      3377
#
#     accuracy                           0.97     11024
#    macro avg       0.96      0.96      0.96     11024
# weighted avg       0.97      0.97      0.97     11024
#
# Value for radius is $3
# Value for radius is $24
# Unique colors in eval_mask (BGR): {(0, 0, 0): 19125, (0, 255, 0): 6032, (0, 255, 255): 28040, (255, 0, 0): 7117, (255, 255, 255): 201830}
# Evaluation Accuracy on Eval Image: 90.58%
# Evaluation Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.74      0.82      7117
#            1       0.60      0.98      0.75      6032
#            2       0.98      0.89      0.93     19125
#            3       0.97      0.94      0.95     28040
#
#     accuracy                           0.91     60314
#    macro avg       0.87      0.89      0.86     60314
# weighted avg       0.93      0.91      0.91     60314
#
# Total time taken: 7649.96 seconds

# %% [markdown]
# ###  Аналіз отриманих значень
#
# З отриманих значень слідує що найоптимальнішою конфігурацією XGBoost з запропонованих параметрів для зображення SS1 являється наступна:
#
# Top 10 Parameters and the best one:
#
# Top 10 Parameters:
# Rank  n_estimators max_depth  eta    radius   n_points   accuracy time(s)
# 1     500          4          0.30   3        16         0.9891   13.74
# 2     500          6          0.30   3        8          0.9890   17.27
# 3     500          6          0.30   3        16         0.9889   18.29
# 4     500          6          0.30   3        24         0.9889   20.87
# 5     300          6          0.30   3        24         0.9888   13.13
# 6     500          4          0.30   3        24         0.9888   15.86
# 7     200          6          0.30   3        24         0.9887   11.29
# 8     500          8          0.30   3        16         0.9887   25.23
# 9     500          8          0.10   3        16         0.9887   24.34
# 10    200          6          0.30   3        8          0.9886   10.15
#
# Best Parameters: {'n_estimators': 500, 'max_depth': 4, 'eta': 0.3, 'radius': 3, 'n_points': 16, 'accuracy': 0.9890676487691413, 'time_elapsed': 13.74214379201294}
#
# Для SS2:
#
# Top 5 Parameters:
# Rank  n_estimators max_depth  eta    radius   n_points   accuracy time(s)
# 1     500          4          0.30   3        24         0.9652   20.30
# 2     300          4          0.30   3        24         0.9645   11.89
# 3     500          4          0.30   3        16         0.9641   18.63
# 4     200          4          0.30   3        24         0.9637   10.94
# 5     500          4          0.30   3        8          0.9630   20.11
# 6     500          6          0.30   3        24         0.9630   25.20
# 7     500          6          0.30   3        16         0.9629   26.51
# 8     300          6          0.30   3        16         0.9624   15.24
# 9     500          6          0.30   3        8          0.9624   22.76
# 10    300          4          0.30   3        16         0.9623   11.31
#
# Best Parameters: {'n_estimators': 500, 'max_depth': 4, 'eta': 0.3, 'radius': 3, 'n_points': 24, 'accuracy': 0.965166908563135, 'time_elapsed': 20.30252120801015}
#
#
# В даному досліді не стоїть задача оптимзації моделі по часу, а лише пошук параметрів які покажуть найвищу точність.
#
# В даному досліді ми визначили найкращі параметри для XGBoost та LBP.  Для кожного із зображень ви обрали найкращий результат. Варто зазначити що топ 10 найкращих результатів для SS1 лежать в межах від 0.9891 до 0.9886. Тобто відхилення незначне і власне будь яка із конфігурації з даного набору дає досить високі результати. Для SS2 результати класифікації лежать в межах від 0.9652 до 0.9623, тут ми маємо більшу різницю між найркащим та гіршив, але зноу ж таки відхилення можна вважати незначним. Для подального дослідження обирами значення де наші конфігурації перетинаються та показують найкращі результи. Це такі значення
#
# Rank  n_estimators max_depth  eta    radius   n_points
# 1     500          4          0.30   3        16
#
# Також з отриманих рузультатів слідує що найкраще модель показала себе при використанні великого радіусу ( radius=3) та значної кількості n_points. проте в даному дослідженні обране нестандартна кількість n_points (зазвичай це n_points = 8 * radius), а зменшена.
#
# Для подальшого дослідження зображень використаємо саме отримані значенні.

# %% [markdown]
# ### Заключна частина:
#
# #### 1. Основні параметри класифікатора:
#
# - **XGBoost** (eXtreme Gradient Boosting):
#   - `n_estimators (кількість дерев)` — цей параметр контролює кількість ітерацій у моделі. Оптимальні значення знайдено на рівні `500` (висока точність класифікації).
#   - `max_depth (глибина дерев)` — впливає на здатність моделі захоплювати складні залежності у даних. Оптимальні значення: `4`.
#   - `eta (швидкість навчання)` — задає інтенсивність навчання. Найкращі результати було досягнуто зі значенням: `0.3`.
#
# - **LBP (Local Binary Pattern)**:
#   - `radius (радіус)` — визначає масштаб аналізу текстури зображення. Найкращі результати досягнуті при `radius = 3`.
#   - `n_points (кількість точок)` — кількість сусідніх точок для створення опису текстури. Обрана конфігурація: `16`.
#
# #### 2. Основні проведені кроки дослідження:
# - **Етап 1:** Реалізація підходу, що поєднує ознаки LBP (текстура) та RGB (колір), щоб отримати комплексні ознаки для побудови класифікатора.
# - **Етап 2:** Виконано підбір оптимальних параметрів для моделі XGBoost за допомогою методу Grid Search для трьох основних гіперпараметрів (`n_estimators`, `max_depth`, `eta`).
# - **Етап 3:** Вдосконалення Grid Search для одночасного підбору параметрів XGBoost (`n_estimators`, `max_depth`, `eta`) разом із параметрами текстурних ознак LBP (`radius`, `n_points`).
# - **Етап 4:** Оцінка отриманих моделей за допомогою метрик `accuracy`, `precision`, `recall`, `f1-score`, класифікаційних звітів та аналізу часу роботи.
# - **Етап 5:** Застосування отриманих конфігурацій до реальних супутникових зображень Sentinel для локалізації класів: вода, рослинність, відкритий ґрунт та урбанізовані області.
#
# #### 3. Отримані результати:
# ##### Для зображення SS1:
# - Найкращі параметри: `{n_estimators: 500, max_depth: 4, eta: 0.3, radius: 3, n_points: 16}`, точність: **98.91%**.
# - Топ-10 параметрів показали точність у межах **98.86–98.91%**, що свідчить про стабільність моделі.
# - Високе значення `radius` покращило здатність моделі захоплювати більш глобальні патерни текстури.
#
# ##### Для зображення SS2:
# - Найкращі параметри: `{n_estimators: 500, max_depth: 4, eta: 0.3, radius: 3, n_points: 24}`, точність: **96.52%**.
# - Топ-10 параметрів показали точність у межах **96.23–96.52%**, що також засвідчує ефективність обраного підходу із використанням LBP разом із XGBoost.
#
# #### 4. Ідеї для подальших досліджень:
# 1. **Дослідження впливу якості зображення**:
#     - Виконати експеримент, щоб перевірити, як різні рівні якості зображення (зашумленість або ступінь стиснення) впливають на класифікацію. Наприклад, порівняти результати класифікації для тренування на чистих та зашумлених зображеннях.
#     - Оцінити відповідність оптимальної конфігурації моделі (параметри XGBoost + LBP) для різних рівнів генерації шуму.
#
# 2. **Удосконалення локальних текстурних ознак**:
#    - Розглянути застосування додаткових покращених текстурних описувачів (таких як HOG або GLCM) щодо поєднання їх із XGBoost.
#    - Дослідити вплив розширеного набору LBP-методів (наприклад, `var`, `ror`) для підвищення чутливості класифікатора до різних класів поверхонь.
#
# 3. **Оптимізація відносно часу навчання**:
#    - Розробити скорингову функцію, що враховує не лише точність, але й час навчання моделі, щоб знайти баланс між швидкодією та точністю (наприклад, за допомогою коефіцієнта ваги, як у дослідженні).
#
# 4. **Генералізація моделі**:
#    - Провести стрес-тести на іншому наборі зображень (крім Sentinel), щоб перевірити універсальність знайдених конфігурацій параметрів.
#    - Використовувати дані з інших супутників чи джерел із різними спектральними характеристиками.
#
# 5. **Розширення класів**:
#    - Додати нові класи (наприклад, водно-болотні угіддя, сільськогосподарські угіддя) і повторити Grid Search для розширеного набору даних.
#
# 6. **Побудова більшої автоматизації**:
#    - Інтегрувати підхід як модуль у повноцінну автоматизовану систему дистанційного зондування Землі, яка виконує попіксельну сегментацію з мінімальним втручанням оператора.
#
# #### 5. Підсумок:
# Проведене дослідження дозволило оптимізувати алгоритм класифікації (LBP + XGBoost) з урахуванням текстурних та кольорових характеристик зображення. Оптимальні конфігурації моделі дають високу точність для досліджених супутникових зображень та забезпечують стабільні результати. Подальші напрями роботи зосереджені на генералізації моделі, аналізі впливу шуму на класифікацію та розширенні можливостей системи.
